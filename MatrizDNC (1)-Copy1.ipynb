# %% [markdown]
# # Automatización de la Matriz de Requerimientos para el Plan Anual de Capacitación
# Esta libreta automatiza la lectura de archivos de evaluación de desempeño y genera una matriz que indica qué trabajadores necesitan capacitación en qué temas.

# %% [markdown]
# ## <b>Importación de librerías </b>
# >

# %% [markdown]
# Importamos las librerías necesarias para manipular archivos Excel, manejar rutas y procesar los datos. En total, se subierón 55 archivos.

# %%
import pandas as pd 
import glob
import numpy as np
import os
# Ruta de la carpeta donde están los archivos csv
carpeta = r"C:\Users\mflor\Downloads\Datos"
# Obtener la lista de archivos csv en la carpeta
archivos= glob.glob(os.path.join(carpeta,"**", "*.csv"), recursive=True)

# %%
print(len(archivos))
# Out:
# 55

# %% [markdown]
# En la siguiente línea de código se muestran todos los archivos que se procesaran.

# %%
archivos
# Out:
# ['C:\\Users\\mflor\\Downloads\\Datos\\Ana Laura Rodríguez Hernández.csv',
#  'C:\\Users\\mflor\\Downloads\\Datos\\Calidadnocapturado.csv',
#  'C:\\Users\\mflor\\Downloads\\Datos\\Copy of MATRIZ DE COMPETENCIAS  DNC- MANTTO ELECTRONICO.csv',
#  'C:\\Users\\mflor\\Downloads\\Datos\\Cristofer Espinosa Lopez.csv',
#  'C:\\Users\\mflor\\Downloads\\Datos\\DAMARIZ SUZETH CELESTINO HERNÁNDEZ.csv',
#  'C:\\Users\\mflor\\Downloads\\Datos\\Daniel Luna Miranda 2.csv',
#  'C:\\Users\\mflor\\Downloads\\Datos\\DANIEL LUNA MIRANDA.csv',
#  'C:\\Users\\mflor\\Downloads\\Datos\\Enrique Alvarez.csv',
#  'C:\\Users\\mflor\\Downloads\\Datos\\finanzas.csv',
#  'C:\\Users\\mflor\\Downloads\\Datos\\GEOVANNI ARÉVALO NÚÑEZ.csv',
#  'C:\\Users\\mflor\\Downloads\\Datos\\IyS1.csv',
#  'C:\\Users\\mflor\\Downloads\\Datos\\IyS2.csv',
#  'C:\\Users\\mflor\\Downloads\\Datos\\ManttoS1.csv',
#  'C:\\Users\\mflor\\Downloads\\Datos\\ManttoS2.csv',
#  'C:\\Users\\mflor\\Downloads\\Datos\\ManttoS3.csv',
#  'C:\\Users\\mflor\\Downloads\\Datos\\ManttoS4.csv',
#  'C:\\Users\\mflor\\Downloads\\Datos\\ManttoS5.csv',
#  'C:\\Users\\mflor\\Downloads\\Datos\\MATRIZ DE COMPETENCIAS  DNC  - INGENIERIA INDUSTRIAL, JIT.csv',
#  'C:\\Users\\mflor\\Downloads\\Datos\\MATRIZ DE COMPETENCIAS  DNC  MANTTO TPM SUSP.csv',
#  'C:\\Users\\mflor\\Downloads\\Datos\\MATRIZ DE COMPETENCIAS  DNC - Comercio Exterior.csv',
#  'C:\\Users\\mflor\\Downloads\\Datos\\MATRIZ DE COMPETENCIAS  DNC AUDITORES DEL SGC.csv',
#  'C:\\Users\\mflor\\Downloads\\Datos\\MATRIZ DE COMPETENCIAS  DNC EHS.csv',
#  'C:\\Users\\mflor\\Downloads\\Datos\\MATRIZ DE COMPETENCIAS  DNC Ing Empaque.csv',
#  'C:\\Users\\mflor\\Downloads\\Datos\\MATRIZ DE COMPETENCIAS  DNC ING. FRENOS.csv',
#  'C:\\Users\\mflor\\Downloads\\Datos\\MATRIZ DE COMPETENCIAS  DNC INGENIERO ENSAMBLE.csv',
#  'C:\\Users\\mflor\\Downloads\\Datos\\MATRIZ DE COMPETENCIAS  DNC INGENIERÍA SUSPENSIONES.csv',
#  'C:\\Users\\mflor\\Downloads\\Datos\\MATRIZ DE COMPETENCIAS  DNC JEFES FRENOS.csv',
#  'C:\\Users\\mflor\\Downloads\\Datos\\MATRIZ DE COMPETENCIAS  DNC Jefes y Manger Assy.csv',
#  'C:\\Users\\mflor\\Downloads\\Datos\\MATRIZ DE COMPETENCIAS  DNC MANAGERS.csv',
#  'C:\\Users\\mflor\\Downloads\\Datos\\MATRIZ DE COMPETENCIAS  DNC MANUFACTURA ENSAMBLE FRENOS.csv',
#  'C:\\Users\\mflor\\Downloads\\Datos\\MATRIZ DE COMPETENCIAS  DNC MANUFACTURA MAQUINADO FRENOS.csv',
#  'C:\\Users\\mflor\\Downloads\\Datos\\MATRIZ DE COMPETENCIAS  DNC MANUFACTURA SUSPENSIONES.csv',
#  'C:\\Users\\mflor\\Downloads\\Datos\\MATRIZ DE COMPETENCIAS  DNC PC&L (Jefaturas).csv',
#  'C:\\Users\\mflor\\Downloads\\Datos\\MATRIZ DE COMPETENCIAS  DNC PC&L (Logistica).csv',
#  'C:\\Users\\mflor\\Downloads\\Datos\\MATRIZ DE COMPETENCIAS  DNC Supervisores mantto br 2 (1).csv',
#  'C:\\Users\\mflor\\Downloads\\Datos\\MATRIZ DE COMPETENCIAS  DNC Supervisores mantto br 2 (2).csv',
#  'C:\\Users\\mflor\\Downloads\\Datos\\MATRIZ DE COMPETENCIAS  DNC Supervisores mantto br 2 (3).csv',
#  'C:\\Users\\mflor\\Downloads\\Datos\\MATRIZ DE COMPETENCIAS  DNC_MXQRP1 PMO.csv',
#  'C:\\Users\\mflor\\Downloads\\Datos\\MATRIZ DE COMPETENCIAS  DNC_QA QMS.csv',
#  'C:\\Users\\mflor\\Downloads\\Datos\\MATRIZ DE COMPETENCIAS  PC&L ALMACEN RECIBO.csv',
#  'C:\\Users\\mflor\\Downloads\\Datos\\MATRIZ DE COMPETENCIAS  PLATING.csv',
#  'C:\\Users\\mflor\\Downloads\\Datos\\MATRIZ DE COMPETENCIAS CALIDAD FRENOS.csv',
#  'C:\\Users\\mflor\\Downloads\\Datos\\MATRIZ DE COMPETENCIAS DNC 2025 Técnicos Ensamble.csv',
#  'C:\\Users\\mflor\\Downloads\\Datos\\MATRIZ DE COMPETENCIAS DNC SUP. SUSPENSIONES.csv',
#  'C:\\Users\\mflor\\Downloads\\Datos\\MATRIZ DNC 2025 JEFES MANTTO.csv',
#  'C:\\Users\\mflor\\Downloads\\Datos\\Matriz DNC_CMD.csv',
#  'C:\\Users\\mflor\\Downloads\\Datos\\Matriz DNC_CMI.csv',
#  'C:\\Users\\mflor\\Downloads\\Datos\\Matriz DNC_PR_Mgrs.csv',
#  'C:\\Users\\mflor\\Downloads\\Datos\\Nocapturados.csv',
#  'C:\\Users\\mflor\\Downloads\\Datos\\OSCAR GILBERTO CASTELLANOS PEREZ.csv',
#  'C:\\Users\\mflor\\Downloads\\Datos\\subup1.csv',
#  'C:\\Users\\mflor\\Downloads\\Datos\\subup2.csv',
#  'C:\\Users\\mflor\\Downloads\\Datos\\subup3.csv',
#  'C:\\Users\\mflor\\Downloads\\Datos\\TPM_frenos1.csv',
#  'C:\\Users\\mflor\\Downloads\\Datos\\TPM_frenos2.csv']

# %% [markdown]
# Los archivos cargados se guardan en tablas (dataframes). A continuación, se muestra el formato de los archivos.
#
# La primera columna contiene los temas,
# en el encabezado se encuentra la nomina del trabajador y al lado de las nominas, la modalidad del tema. Para saber si el tema necesita ser cubierto, nos interesa la tercera columna correspondiente a la nomina del trabajador. Esta contiene claves (0,1,2,3)
#
# - 3: Indica urgencia ALTA- Agregar al PAC  actual y programar entrenamiento  en  los primeros 4 meses (CSR´S, SGC, SGA, Regulatorios)
# - 2 : Indica urgencia MEDIA- Agregar al PAC  y programar en los primeros 8 meses (COMPETENCIAS DE DESARROLLO)
# - 1: Indica urgencia BAJA- Agregar al PAC y Programar dentro de los 12 meses
# - 0: CUBIERTO- Competencia cubierta
#
# (PAC significa Plan Anual de Capacitación)

# %% [markdown]
# ### Formato de los archivos cargados
# ![Archivo Limpio](DNC2.png)

# %%
#lista de dataframes
dataframes = [pd.read_csv(archivo,encoding='utf-8',low_memory=False) for archivo in archivos]

# %% [markdown]
# ## <b>Limpieza de los datos </b>

# %% [markdown]
# Antes de generar la matriz de requerimientos de capacitación, es fundamental asegurarse de que los archivos de entrada tengan el formato adecuado para evitar errores en el procesamiento.
#
# Primero, se verifica que existan las columnas clave: taller y curso, ya que contienen la información necesaria para identificar si un trabajador asistió a una capacitación.
#
# Después, se realiza una conversión de celdas vacías. Es común que algunos archivos contengan valores nulos (NaN). Para prevenir errores durante el análisis, estos valores se reemplazan por cadenas vacías (""), lo cual permite trabajar con los datos de manera más consistente.

# %%
#Lidiar con valores nulos
i=1
for tabla in dataframes:
    # Verificar si las columnas 'Curso' y 'Taller' existen antes de hacer la conversión
    if 'Curso' in tabla.columns:
        tabla["Curso"] = tabla["Curso"].fillna("").astype(str)
    else:
        print("Columna 'Curso' no encontrada en el DataFrame %i"%i)
        print("La ubicación del archivo es %s"%archivos[i-1])

    if 'Taller' in tabla.columns:
        tabla["Taller"] = tabla["Taller"].fillna("").astype(str)
    else:
        print("Columna 'Taller' no encontrada en el DataFrame")
    i+=1

# %% [markdown]
# ## Ejemplo

# %% [markdown]
# En la siguiente línea del código se muestra el formato de los 55 archivos analizados. En el encabezado se muestra el número de nomina, mientras que del lado izquierdo se muestra el tema. Esta tabla evalua el rendimiento del  trabajor.

# %%
dataframes[0]
# Out:
#                                                 Tema  761268.0  761268.1  \
# 0  Conocimiento y aplicación de las herramientas ...         3         1
# 1     Conocimiento e Interpretación de planos y GD&T         3         1
# 2              Competencia en IATF 16949 (Formación)         3         1
# 3                          Certificación en VDA 6.3          2         1
# 4  Conocimiento y aplicación de Problem Solving V...         3         1
# 5  Conocimiento del producto y proceso de manufac...         3         2
# 6  Conocimiento de requisitos específicos del cli...         3         1
# 7                      Competencia en auditoria DTLD         2         1
# 8  Conocimiento y aplicación de Herramientas de S...         3         2
# 9  Conocimiento e interpretación de CQI-11, CQI-1...         3         1
#
#    761268.2  776169.0  776169.1  776169.2  769466.0  769466.1  769466.2  \
# 0         2         3         1         2         3         1         2
# 1         2         3         1         2         3         1         2
# 2         2         3         1         2         3         1         2
# 3         1         2         1         1         3         1         2
# 4         2         3         1         2         3         1         2
# 5         1         3         2         1         3         2         1
# 6         2         3         1         2         3         1         2
# 7         1         2         1         1         3         1         2
# 8         1         3         2         1         3         2         1
# 9         2         3         1         2         3         1         2
#
#    773190.0  773190.1  773190.2  774233.0  774233.1  774233.2 Curso Taller
# 0         3         1         2         3         1         2
# 1         3         1         2         3         1         2
# 2         3         1         2         3         1         2
# 3         3         1         2         2         1         1
# 4         3         1         2         3         1         2
# 5         3         2         1         3         2         1
# 6         3         1         2         3         1         2
# 7         3         1         2         2         1         1
# 8         3         2         1         3         2         1
# 9         3         1         2         3         1         2

# %% [markdown]
# ### <b>Agrupación de temas por equivalencia de contenido<b>

# %% [markdown]
# Se identificó que ciertos cursos o temas, aunque tienen nombres distintos, abordan los mismos contenidos o competencias. Por lo tanto, se agruparon bajo una categoría común para evitar duplicidad y facilitar la interpretación de los datos.

# %%
diccionario_temas = {
    #"Core Tools": "Core Tools",
    "Core ToolsAPQP":"Core Tools - APQP 3ra Edición",
    "Core ToolsPPAP": "Core Tools - PPAP 4ta Edición",
    "PLC_HMI": ["PLC / HMI","PLC, HMI"],
    "IATF": "IATF",
    "registros_calidad":"Uso de las hojas de liberación y registros de calidad",
    "AMEF": "AMEF",
    "VDA": "VDA",
    "Legislacion":"legislacion mexicana aplicable a procesos y actividades de hitachi", #antes STPS
    "TPM": ["TPM","Administracion de mantenimiento (TPM) Kpis, controles, estrategias, metodologias."],#antes de kpi
    "CRS (Requerimientos Especificos del Cliente)": ["CRS (Requerimientos Especificos del Cliente)", "Conocimiento en requerimientos específicos de cliente","Requerimientos de clientes","requerimientos específicos de cliente"],
    #antes CQI12,CQI11
    "SPC": ["SPC", "estadistico",'estadístico', 'Manejo estadistico de datos','control de proceso'],
    "Estadistica": "Estadística descriptiva e inferencial",
    "alturas":"alturas",
    "montacargas":"montacargas",
    "electricidad": ["electricidad", "subestacion","Fundamentos Eléctricos Baja Tensión (480, 200,110 VCA)"],
    "Conocimientos en electronica de control":"Conocimientos en electrónica de control",
    #"Auditorías electrónicas y fiscalización":"Auditorías electrónicas y fiscalización",
    #"Principios básicos de control electrico": "Principios básicos de control electrico",
    "Soldadura":["Trabajos de corte y soldadura", "Soldadura Industrial","Conocimiento basicos de soldadura y su aplicacion, por arco electrico,aplicación de TIG y MIG"],
    "NOM_2": "NOM-002 SEMARNAT limites maximos permisibles en descargas de aguas",
    "STPS": "STPS",
    "Torno": "Conocimientos en el uso de maquinas y herramientas convencionales(torno,fresadora,rectificadora,etc)para elaboración de piezas mecanicas",
    "termicos":"termicos",
    "Gestion_Calidad": ["Conocimiento en sistemas de calidad", "Sistema Gestion Calidad", "sistemas de calidad"],
    #"registros_calidad":"Uso de las hojas de liberación y registros de calidad",
    "APQP":["APQP (Planificación avanzada de la calidad del producto)","APQP 3era Edición Mar 2024"],
    "Absodex":  "Absodex",
    "confinado":"Trabajos en espacios confinados",
    "Celda_Hull":"Interpretacion de Celda Hull",
    "filtarción":"filtarción",
    "corrosion": "Fundamentos de corrosión",
    "AIAG 16949": "AIAG 16949",
    "ISO 14000": "ISO 14000",
    "Control inventarios": ["Control inventarios","inventarios"],
    "Lean Manufacturing": "Lean Manufacturing",
    "Almacenaje": "almacen",
    "Manejo de Control Sinumerik 840d": "Manejo de Control Sinumerik 840d",
    "Conocimiento de tipos de sensores": "Conocimiento de tipos de sensores",
    "Maint": "Maint",
    "Logística y Cadena de Suministros": "Logística y Cadena de Suministros",
    "Carta Porte": "Carta Porte",
    "CTPAT & OEA": ["CTPAT & OEA","Certificación CTPAT / OEA"],
    "lubricacion":"lubricación",
    "contrabando":"contrabando",
    "ComercioE":["Reglas Generales de Comercio Exterior","Reglas Generales de Comercio Exterior: Actualización y cumplimiento"],

    "Despacho":"despacho",
    "INCOTERMS": "INCOTERMS",
    "CalculoE":"Cálculo de contribuciones al Comercio Exterior",
    "termografia":"termografia",
    "InterpretaciónM":["Interpretación de planos mecánicos","interpretacion de planos"],
    "Conocimiento del producto": "Conocimiento del producto",
    "dibujoT":"Conocimiento e interpretación de diseños mecánicos(dibujo tecnico)",
    "Solid Works":["Conocimientos basicos en software de diseño solid Works","Solid Works", "Solidworks"],
    "equipos_de_medición": ["Manejo de equipos de medición", "medicion"],
    "aduanal":["Glosa e identificadores del pedimento aduanal","Negociación con Agentes Aduanales y Transportes","Glosa e identificadores del pedimento aduanal", "Glosa y llenado de pedimento"],
    "GestionRC":"Gestion de riesgos y cumplimientos",
    "PlanificacionEyT":"Planificación estrategica y toma de decisiones",
    "Presupuestación_y_Control_de_Costos": ["Presupuestación y Control de Costos","Analisis de Costos","Costos Estándar"],
    "MSA": "MSA",
    "PPAP": ["PPAP 4A. EDICIÓN","PPAP (Proceso de Aprobación de Piezas de Producción)","PPAP 4ta Edición Mar 2006"],
    #CQI ´S (9,11,12 y 15)
    "DG&T": ["DG&T", "DG", "GD", "Tolerancias Geométricas"],
    "CQI-8": ["CQI-8", "CQI8", "CQI 8", "CQI- 8", "CQI -8", "CQI - 8"],
    "CQI-9": ["CQI-9", "CQI9", "CQI 9", "CQI- 9", "CQI -9", "CQI - 9"],
    "CQI-11": ["CQI-11", "CQI11", "CQI 11", "CQI- 11", "CQI -11", "CQI - 11"],
    "CQI-12": ["CQI-12", "CQI12", "CQI 12", "CQI- 12", "CQI -12", "CQI - 12"],
    "CQI-14": ["CQI-14", "CQI14", "CQI 14", "CQI- 14", "CQI -14", "CQI - 14"],
    "CQI-15": ["CQI-15", "CQI15", "CQI 15", "CQI- 15", "CQI -15", "CQI - 15"],
    #"CQI-19": ["CQI-19", "CQI19", "CQI 19", "CQI- 19", "CQI -19", "CQI - 19"],
    "CQI-20": ["CQI-20", "CQI20", "CQI 20", "CQI- 20", "CQI -20", "CQI - 20"],
    "Instructores": ["Instructor interno","instructores","instructor"],
    "Measure Link": "Measure Link",
    "Entendimiento de Plan de Control": ["Entendimiento de Plan de Control","Control plan", "Plan de Control 1era edición Ene 2024"],
    "gagetrak": "gagetrak",
    "ILUO": "ILUO",
    "Administracion de recursos": "Administracion de recursos",
    "Uso de Portales de Clientes": ["Uso de Portales de Clientes","Conocimiento y manejo de portales de clientes apartado de capacidades","Portales de Clientes"],
    "14001": "14001",
    "Sigma": "Sigma",
    "SGC": "SGC",
    "Ingles": ["Ingles","Idioma inglés", "inglés"],
    "Aston-G": "Aston-G",
    "GQUICS": "GQUICS",
    "CSF Stellantis": "CSF Stellantis",
    "CSF Nissan": "Nissan",
    "CSR Mazda": "Mazda",
    "CSR Ford": ["CSR Ford","csr's ford"],
    "CSF Toyota": "CSF Toyota",
    "8 DS": ["8 DS", "8D","fallas", "Herramientas de solución de problemas","solucion de problemas",
            "resolucion de problemas","analisis y solucion de problemas"],
    "Normas metrologia": ["Normas metrologia","normas aplicables para laboratorios de metrologia.",
                          "normas aplicables para laboratorios de metrologia"],


    "PFMEA": "PFMEA",
    #"Analisis de Costos":"Analisis de Costos",
    "Habilidades de negociacion":"Habilidades de negociacion",
    "LOTO":"LOTO",
    "camaras":["camaras","sistemas de vision y escaners"],
    "sustancias":["sustancias","quimic"],
    #"Auditorías electrónicas y fiscalización": "Auditorías electrónicas y fiscalización",
    "emergencia":["incendio","gestion de la atencion a emergencias","primeros auxilios uso de dea",
    "introduccion a rescate"],

    "hidraulica_neumatica_mecanica":["neumatica / hidraulica","Neumatica/Hidraulica", "mecanica,hidraulica,neumatica", 
                                     "Conocimientos de mecanica", "Conocimiento en sistemas hidráulicos / neumaticos", "Hidraulica/Neumatica"],
    "Floor Management":["Floor Managment","floor management"],
    "Manejo de personal":["Manejo de personal","administracion de personal"],
    "Conocimiento en sistemas de produccion":["Conocimiento en sistemas de produccion","sistemas de produccion"],
    "AnalisisInst":"Análisis instrumental (AA, ICP, HPLC, FTIR, etc.)",
    "Panasonic":"Panasonic",
    "Denso":"Denso",
    "FANUC":"FANUC",
    "KUKA":"KUKA",
    "IAI_Yamaha":["IAI y Yamaha","IAI"],
    "Correcto_analisis":"Correcto análisis, auditoría y correcciones del Sistema de Control de",
    "CAMPA":"CAMPA",

    "ISO 31000":"ISO 31000",
    "ISO 9000":"ISO 9000:2015",
    "ISO 19011":"ISO 19011:2018",
    "ISO 9001": "ISO 9001:2015",
    "Conocimiento en la aplicación de las Interpretaciones Sancionadas":"Conocimiento en la aplicación de las Interpretaciones Sancionadas",
    
    "immex":"immex",
    "anexo 24":"anexo 24",
    "tiempo": ["coordinacion de actividades","administracion del tiempo"],
    #"coordinacion de actividades":"coordinacion de actividades",
    "iso 4500":["iso 4500:2018","iso 4500"],
    "nfpa 70e":"nfpa 70e",
    "siemens y allen bradley":["manejo de software plc siemens y allen bradley","allen bradley"],
    "prensas kistler":"conocimiento de servo prensas kistler",
    "conocimiento manejos  de robots staubli":["conocimiento manejos  de robots staubli","staubli"],
    "autocad":"autocad",
    "calculo de valor de contenido regional":"calculo de valor de contenido regional",
    "calculo oee":["calculo oee",'oee'],
   
    
    "ansi b11.19":"ansi b11.19",
    "sistema stop_safe start":"sistema stop / safe start",#*
    #"instructores":"instructores",#*
    "tratamiento de aguas residuales":"tratamiento de aguas residuales",
    "descarbonizacion":"descarbonizacion 2030",
    "economia circular":"economia circular",
    "gases":"calculos de gases de efecto invernadero ( coa's , lau)",
    "audi_lison":"audi - lison",
    "FORD_EDDL":"ford - eddl, gpp, cmms",
    "excelencia operacional": "excelencia operacional",
    "control y manejo de indicadores kpi": ["control y manejo de indicadores kpi",'kpi'],
    "finanzas para no financieros": "finanzas para no financieros",
    "habilidades gerenciales y de negociacion":["habilidades gerenciales","Habilidades de negociacion"],
    "cash2":["conocimiento de p&l (profit and loss) file","cash flow training"],
    "capacidad de las lineas": "capacidad de las lineas",
    "manejo y ejecucion de wms":"manejo y ejecucion de wms",
    "caracteristicas especiales del proceso y producto":"caracteristicas especiales del proceso y producto",
    "vsm mixel model":"vsm mixel model",
    "creating level pull":"creating level pull",
    "conocimiento de equipos de alta presion maximator":["conocimiento de equipos de alta presion maximator","maximator"],
    "sga training":"sga training",
    "Excel":"excel",
    "Aqua pro":"Aqua pro",
    #
    "maquina":"Interpretación de diagramas y manuales de maquina",
    "mejoras":"Desarrollo e implementación de mejoras",
    "gruas":"Manejo de gruas viajeras",
    '4ms':'4ms',
    "csr's honda":"csr's honda",
    "job observation":"job observation",
    "csr's subaru": "csr's subaru"


    


    
    
}
len(diccionario_temas)
# Out:
# 148

# %% [markdown]
# La siguiente función encuentra la clave correspondiente que agrupara los temas, utilizando el diccionario anterior.

# %%
from unidecode import unidecode  # Para eliminar acentos

# %%
def encontrar_nuevo_indice(texto):
    texto = unidecode(str(texto).strip().lower())  # Asegurar que el valor es string y normalizar
    # Condición especial para "Core Tools"
    if "core tools" in texto and ("edición" not in texto and "edicion" not in texto):
        return "Core Tools"

    for clave, valores in diccionario_temas.items():
        if isinstance(valores, list):  # Si hay una lista de sinónimos
            for valor in valores:
                valor_normalizado = unidecode(valor.strip().lower())  # Normalizar cada valor
                if valor_normalizado in texto:
                    return clave
        else:  # Si es un único valor
            valor_normalizado = unidecode(valores.strip().lower())  # Normalizar el valor único
            if valor_normalizado in texto:
                return clave
    return texto  # Si no hay coincidencia, se deja el mismo índice

# %% [markdown]
# ## <b>Agrupar los temas de cada archivo cargado<b>

# %% [markdown]
# Utilizando la función anterior los temas de cada archivo se reemplaza por la clave correspondiente.

# %%
for tabla in dataframes:
    temas=list(tabla.Tema)
    tabla.Tema = tabla.Tema.map(encontrar_nuevo_indice)
    #print(tabla)

# %% [markdown]
# ## <b>Cargar la tabla de Requerimientos y Plan Anual de Capacitacion<b>

# %% [markdown]
# Esta tabla contiene como encabezados las claves o nombres de los temas de capacitación y utiliza como índice la nómina de los trabajadores.
# El objetivo es identificar, para cada trabajador, si necesita revisar o capacitarse en un tema específico.
# Para ello, si un trabajador requiere capacitación en un tema, la celda correspondiente se marcará con una "x"; en caso contrario, la celda se deja en blanco (o NaN).

# %%
Principal=pd.read_csv(r'C:\Users\mflor\Downloads\Principal2.csv',index_col=0,encoding='utf-8')
Principal
# Out:
#          Core Tools  Core ToolsAPQP  Core ToolsPPAP  PLC_HMI  IATF  AMEF  VDA  \
# nominas
# 776532          NaN             NaN             NaN      NaN   NaN   NaN  NaN
# 770479          NaN             NaN             NaN      NaN   NaN   NaN  NaN
# 763354          NaN             NaN             NaN      NaN   NaN   NaN  NaN
# 775239          NaN             NaN             NaN      NaN   NaN   NaN  NaN
# 861202          NaN             NaN             NaN      NaN   NaN   NaN  NaN
# ...             ...             ...             ...      ...   ...   ...  ...
# 762375          NaN             NaN             NaN      NaN   NaN   NaN  NaN
# 761244          NaN             NaN             NaN      NaN   NaN   NaN  NaN
# 772870          NaN             NaN             NaN      NaN   NaN   NaN  NaN
# 774254          NaN             NaN             NaN      NaN   NaN   NaN  NaN
# 765420          NaN             NaN             NaN      NaN   NaN   NaN  NaN
#
#          SPC  Estadistica  alturas  ...  Excel  Aqua pro  TPM  maquina  \
# nominas                             ...
# 776532   NaN          NaN      NaN  ...    NaN       NaN  NaN      NaN
# 770479   NaN          NaN      NaN  ...    NaN       NaN  NaN      NaN
# 763354   NaN          NaN      NaN  ...    NaN       NaN  NaN      NaN
# 775239   NaN          NaN      NaN  ...    NaN       NaN  NaN      NaN
# 861202   NaN          NaN      NaN  ...    NaN       NaN  NaN      NaN
# ...      ...          ...      ...  ...    ...       ...  ...      ...
# 762375   NaN          NaN      NaN  ...    NaN       NaN  NaN      NaN
# 761244   NaN          NaN      NaN  ...    NaN       NaN  NaN      NaN
# 772870   NaN          NaN      NaN  ...    NaN       NaN  NaN      NaN
# 774254   NaN          NaN      NaN  ...    NaN       NaN  NaN      NaN
# 765420   NaN          NaN      NaN  ...    NaN       NaN  NaN      NaN
#
#          mejoras  gruas  4ms  csr's honda  job observation  csr's subaru
# nominas
# 776532       NaN    NaN  NaN          NaN              NaN           NaN
# 770479       NaN    NaN  NaN          NaN              NaN           NaN
# 763354       NaN    NaN  NaN          NaN              NaN           NaN
# 775239       NaN    NaN  NaN          NaN              NaN           NaN
# 861202       NaN    NaN  NaN          NaN              NaN           NaN
# ...          ...    ...  ...          ...              ...           ...
# 762375       NaN    NaN  NaN          NaN              NaN           NaN
# 761244       NaN    NaN  NaN          NaN              NaN           NaN
# 772870       NaN    NaN  NaN          NaN              NaN           NaN
# 774254       NaN    NaN  NaN          NaN              NaN           NaN
# 765420       NaN    NaN  NaN          NaN              NaN           NaN
#
# [343 rows x 149 columns]

# %% [markdown]
# ## <b>Buscar las nominas de los trabajadores que tienen una necesidad de capacitación en uno de los temas que son curso o  taller<b>

# %% [markdown]
# En este bloque se procesa cada uno de los 55 archivos cargados (dataframes) para identificar los temas (cursos o talleres) en los que cada trabajador requiere capacitación.

# %%
nominas=[]
for tabla in dataframes:
    #Se determina la posición de la columna llamada "Curso" para usarla como referencia en la tabla.
    columna_curso_idx = tabla.columns.get_loc("Curso")
    columna_curso_idx
    Filtrar filas con necesidad de capacitación:
    #Se seleccionan las filas donde en las columnas "Curso" o "Taller" aparece una "x" (sin importar mayúsculas o minúsculas), 
    #lo que indica que el tema es un curso o taller activo para el trabajador.
    indices_x = list(tabla[(tabla["Curso"].str.lower()== "x") | (tabla["Taller"].str.lower() == "x")].index)
    indices_x
    #print(tabla.Curso.dtypes,tabla.Taller.dtypes)
    # Ademas se busca si un trabajador tiene un numero distinto de 0 en la tercer columna correspondiente a su nomina. Si esto sucede 
    # el trabajador requiere capacitación.
    for indice in indices_x: 
            for i in range(3, columna_curso_idx, 3):#columna
                # Obtener el valor de la tercera columna 
                valor = tabla.iloc[indice,i]
                # Si el valor obtenido es diferente de 0 y no vacio indica que el trabajador requiere capacitación. 
                #En este caso, se crea una lista con pares [Tema, Nómina] que vinculan al trabajador con el tema que debe revisar.
                if isinstance(valor, (int, float, np.number)) and valor != 0 and pd.notnull(valor):
                    nominas.append([tabla.Tema[indice], float(tabla.columns[i])])

# %%
len(nominas)
# Out:
# 2785

# %%
nominas
# Out:
# [['AMEF', 773143.2],
#  ['AMEF', 765736.2],
#  ['AMEF', 776477.2],
#  ['AMEF', 761870.2],
#  ['AMEF', 764984.2],
#  ['AMEF', 773752.2],
#  ['AMEF', 776206.2],
#  ['AMEF', 773751.2],
#  ['Entendimiento de Plan de Control', 773143.2],
#  ['Entendimiento de Plan de Control', 765736.2],
#  ['Entendimiento de Plan de Control', 776477.2],
#  ['Entendimiento de Plan de Control', 761870.2],
#  ['Entendimiento de Plan de Control', 764984.2],
#  ['Entendimiento de Plan de Control', 773752.2],
#  ['Entendimiento de Plan de Control', 776206.2],
#  ['Entendimiento de Plan de Control', 773751.2],
#  ['IATF', 776477.2],
#  ['IATF', 761870.2],
#  ['IATF', 773752.2],
#  ['IATF', 776206.2],
#  ['IATF', 773751.2],
#  ['SPC', 773143.2],
#  ['SPC', 765736.2],
#  ['SPC', 776477.2],
#  ['SPC', 761870.2],
#  ['SPC', 764984.2],
#  ['SPC', 773752.2],
#  ['SPC', 776206.2],
#  ['SPC', 773751.2],
#  ['ILUO', 773752.2],
#  ['ILUO', 776206.2],
#  ['ILUO', 773751.2],
#  ['8 DS', 773143.2],
#  ['8 DS', 765736.2],
#  ['8 DS', 776477.2],
#  ['8 DS', 761870.2],
#  ['8 DS', 764984.2],
#  ['8 DS', 773752.2],
#  ['8 DS', 776206.2],
#  ['8 DS', 773751.2],
#  ['apqp (planificacion avanzada del producto)', 773143.2],
#  ['apqp (planificacion avanzada del producto)', 765736.2],
#  ['apqp (planificacion avanzada del producto)', 776477.2],
#  ['apqp (planificacion avanzada del producto)', 761870.2],
#  ['apqp (planificacion avanzada del producto)', 764984.2],
#  ['apqp (planificacion avanzada del producto)', 773752.2],
#  ['apqp (planificacion avanzada del producto)', 776206.2],
#  ['apqp (planificacion avanzada del producto)', 773751.2],
#  ['MSA', 773143.2],
#  ['MSA', 765736.2],
#  ['MSA', 776477.2],
#  ['MSA', 761870.2],
#  ['MSA', 764984.2],
#  ['MSA', 773752.2],
#  ['MSA', 776206.2],
#  ['MSA', 773751.2],
#  ['ppap', 773143.2],
#  ['ppap', 765736.2],
#  ['ppap', 776477.2],
#  ['ppap', 761870.2],
#  ['ppap', 764984.2],
#  ['ppap', 773752.2],
#  ['ppap', 776206.2],
#  ['ppap', 773751.2],
#  ['CRS (Requerimientos Especificos del Cliente)', 773143.2],
#  ['CRS (Requerimientos Especificos del Cliente)', 765736.2],
#  ['CRS (Requerimientos Especificos del Cliente)', 776477.2],
#  ['CRS (Requerimientos Especificos del Cliente)', 761870.2],
#  ['CRS (Requerimientos Especificos del Cliente)', 764984.2],
#  ['CRS (Requerimientos Especificos del Cliente)', 773752.2],
#  ['CRS (Requerimientos Especificos del Cliente)', 776206.2],
#  ['CRS (Requerimientos Especificos del Cliente)', 773751.2],
#  ['VDA', 773143.2],
#  ['VDA', 765736.2],
#  ['VDA', 776477.2],
#  ['VDA', 761870.2],
#  ['VDA', 764984.2],
#  ['VDA', 773752.2],
#  ['VDA', 776206.2],
#  ['VDA', 773751.2],
#  ['PLC_HMI', 767089.2],
#  ['PLC_HMI', 769547.2],
#  ['PLC_HMI', 770928.2],
#  ['PLC_HMI', 771697.2],
#  ['PLC_HMI', 772164.2],
#  ['PLC_HMI', 767089.2],
#  ['PLC_HMI', 769547.2],
#  ['PLC_HMI', 770928.2],
#  ['PLC_HMI', 771697.2],
#  ['PLC_HMI', 772164.2],
#  ['camaras', 771697.2],
#  ['camaras', 772164.2],
#  ['Panasonic', 767089.2],
#  ['Panasonic', 769547.2],
#  ['Panasonic', 770928.2],
#  ['Panasonic', 771697.2],
#  ['Panasonic', 772164.2],
#  ['Denso', 767089.2],
#  ['Denso', 770928.2],
#  ['Denso', 771697.2],
#  ['Denso', 772164.2],
#  ['IAI_Yamaha', 767089.2],
#  ['IAI_Yamaha', 769547.2],
#  ['IAI_Yamaha', 770928.2],
#  ['IAI_Yamaha', 771697.2],
#  ['IAI_Yamaha', 772164.2],
#  ['LOTO', 767089.2],
#  ['LOTO', 769547.2],
#  ['LOTO', 770928.2],
#  ['LOTO', 771697.2],
#  ['LOTO', 772164.2],
#  ['Measure Link', 763051.2],
#  ['Measure Link', 765514.2],
#  ['Measure Link', 773072.2],
#  ['Measure Link', 761388.2],
#  ['Measure Link', 771166.2],
#  ['Measure Link', 764426.2],
#  ['Measure Link', 761746.2],
#  ['Measure Link', 771379.2],
#  ['Measure Link', 763311.2],
#  ['Measure Link', 773495.2],
#  ['Measure Link', 773287.2],
#  ['Measure Link', 772902.2],
#  ['Measure Link', 773755.2],
#  ['Measure Link', 771373.2],
#  ['Measure Link', 770183.2],
#  ['Entendimiento de Plan de Control', 763051.2],
#  ['Entendimiento de Plan de Control', 765514.2],
#  ['Entendimiento de Plan de Control', 773072.2],
#  ['Entendimiento de Plan de Control', 761388.2],
#  ['Entendimiento de Plan de Control', 771166.2],
#  ['Entendimiento de Plan de Control', 764426.2],
#  ['Entendimiento de Plan de Control', 761746.2],
#  ['Entendimiento de Plan de Control', 771379.2],
#  ['Entendimiento de Plan de Control', 763311.2],
#  ['Entendimiento de Plan de Control', 773495.2],
#  ['Entendimiento de Plan de Control', 773287.2],
#  ['Entendimiento de Plan de Control', 772902.2],
#  ['Entendimiento de Plan de Control', 773755.2],
#  ['Entendimiento de Plan de Control', 771373.2],
#  ['Entendimiento de Plan de Control', 770183.2],
#  ['IATF', 764426.2],
#  ['IATF', 761746.2],
#  ['IATF', 771379.2],
#  ['IATF', 763311.2],
#  ['IATF', 773495.2],
#  ['IATF', 773287.2],
#  ['IATF', 771373.2],
#  ['SPC', 763051.2],
#  ['SPC', 765514.2],
#  ['SPC', 773072.2],
#  ['SPC', 761388.2],
#  ['SPC', 771166.2],
#  ['SPC', 764426.2],
#  ['SPC', 761746.2],
#  ['SPC', 771379.2],
#  ['SPC', 763311.2],
#  ['SPC', 773495.2],
#  ['SPC', 773287.2],
#  ['SPC', 772902.2],
#  ['SPC', 773755.2],
#  ['SPC', 771373.2],
#  ['SPC', 770183.2],
#  ['gagetrak', 771166.2],
#  ['gagetrak', 764426.2],
#  ['gagetrak', 761746.2],
#  ['gagetrak', 771379.2],
#  ['gagetrak', 763311.2],
#  ['gagetrak', 773495.2],
#  ['gagetrak', 773287.2],
#  ['gagetrak', 771373.2],
#  ['ILUO', 773072.2],
#  ['ILUO', 764426.2],
#  ['ILUO', 761746.2],
#  ['ILUO', 771379.2],
#  ['ILUO', 763311.2],
#  ['ILUO', 773495.2],
#  ['ILUO', 773287.2],
#  ['ILUO', 771373.2],
#  ['8 DS', 763051.2],
#  ['8 DS', 765514.2],
#  ['8 DS', 773072.2],
#  ['8 DS', 761388.2],
#  ['8 DS', 771166.2],
#  ['8 DS', 764426.2],
#  ['8 DS', 761746.2],
#  ['8 DS', 771379.2],
#  ['8 DS', 763311.2],
#  ['8 DS', 773495.2],
#  ['8 DS', 773287.2],
#  ['8 DS', 772902.2],
#  ['8 DS', 773755.2],
#  ['8 DS', 771373.2],
#  ['DG&T', 763051.2],
#  ['DG&T', 765514.2],
#  ['DG&T', 773072.2],
#  ['DG&T', 761388.2],
#  ['DG&T', 771166.2],
#  ['DG&T', 764426.2],
#  ['DG&T', 761746.2],
#  ['DG&T', 771379.2],
#  ['DG&T', 763311.2],
#  ['DG&T', 773495.2],
#  ['DG&T', 773287.2],
#  ['DG&T', 772902.2],
#  ['DG&T', 773755.2],
#  ['DG&T', 771373.2],
#  ['DG&T', 770183.2],
#  ['equipos_de_medición', 763051.2],
#  ['equipos_de_medición', 765514.2],
#  ['equipos_de_medición', 773072.2],
#  ['equipos_de_medición', 761388.2],
#  ['equipos_de_medición', 771166.2],
#  ['equipos_de_medición', 764426.2],
#  ['equipos_de_medición', 761746.2],
#  ['equipos_de_medición', 771379.2],
#  ['equipos_de_medición', 763311.2],
#  ['equipos_de_medición', 773495.2],
#  ['equipos_de_medición', 773287.2],
#  ['equipos_de_medición', 772902.2],
#  ['equipos_de_medición', 773755.2],
#  ['equipos_de_medición', 771373.2],
#  ['equipos_de_medición', 770183.2],
#  ['Normas metrologia', 763051.2],
#  ['Normas metrologia', 765514.2],
#  ['Normas metrologia', 773072.2],
#  ['Normas metrologia', 761388.2],
#  ['Normas metrologia', 771166.2],
#  ['Normas metrologia', 764426.2],
#  ['Normas metrologia', 761746.2],
#  ['Normas metrologia', 771379.2],
#  ['Normas metrologia', 763311.2],
#  ['Normas metrologia', 773495.2],
#  ['Normas metrologia', 773287.2],
#  ['Normas metrologia', 772902.2],
#  ['Normas metrologia', 773755.2],
#  ['Normas metrologia', 771373.2],
#  ['Normas metrologia', 770183.2],
#  ['CRS (Requerimientos Especificos del Cliente)', 763051.2],
#  ['CRS (Requerimientos Especificos del Cliente)', 765514.2],
#  ['CRS (Requerimientos Especificos del Cliente)', 773072.2],
#  ['CRS (Requerimientos Especificos del Cliente)', 761388.2],
#  ['CRS (Requerimientos Especificos del Cliente)', 771166.2],
#  ['CRS (Requerimientos Especificos del Cliente)', 764426.2],
#  ['CRS (Requerimientos Especificos del Cliente)', 761746.2],
#  ['CRS (Requerimientos Especificos del Cliente)', 771379.2],
#  ['CRS (Requerimientos Especificos del Cliente)', 763311.2],
#  ['CRS (Requerimientos Especificos del Cliente)', 773495.2],
#  ['CRS (Requerimientos Especificos del Cliente)', 773287.2],
#  ['CRS (Requerimientos Especificos del Cliente)', 772902.2],
#  ['CRS (Requerimientos Especificos del Cliente)', 773755.2],
#  ['CRS (Requerimientos Especificos del Cliente)', 771373.2],
#  ['CRS (Requerimientos Especificos del Cliente)', 770183.2],
#  ['VDA', 763051.2],
#  ['VDA', 765514.2],
#  ['VDA', 773072.2],
#  ['VDA', 761388.2],
#  ['VDA', 771166.2],
#  ['VDA', 764426.2],
#  ['VDA', 761746.2],
#  ['VDA', 771379.2],
#  ['VDA', 763311.2],
#  ['VDA', 773495.2],
#  ['VDA', 773287.2],
#  ['VDA', 772902.2],
#  ['VDA', 773755.2],
#  ['VDA', 771373.2],
#  ['VDA', 770183.2],
#  ['InterpretaciónM', 761720.2],
#  ['InterpretaciónM', 761984.2],
#  ['InterpretaciónM', 762243.2],
#  ['InterpretaciónM', 763052.2],
#  ['InterpretaciónM', 767167.2],
#  ['InterpretaciónM', 769062.2],
#  ['InterpretaciónM', 765788.2],
#  ['InterpretaciónM', 776343.2],
#  ['InterpretaciónM', 776616.2],
#  ['SPC', 761720.2],
#  ['SPC', 761984.2],
#  ['SPC', 762243.2],
#  ['SPC', 763052.2],
#  ['SPC', 767167.2],
#  ['SPC', 769062.2],
#  ['SPC', 765788.2],
#  ['SPC', 776343.2],
#  ['SPC', 776616.2],
#  ['termicos', 761720.2],
#  ['termicos', 761984.2],
#  ['termicos', 762243.2],
#  ['termicos', 763052.2],
#  ['termicos', 767167.2],
#  ['termicos', 769062.2],
#  ['termicos', 765788.2],
#  ['termicos', 776343.2],
#  ['termicos', 776616.2],
#  ['CQI-11', 761720.2],
#  ['CQI-11', 761984.2],
#  ['CQI-11', 762243.2],
#  ['CQI-11', 763052.2],
#  ['CQI-11', 767167.2],
#  ['CQI-11', 769062.2],
#  ['CQI-11', 765788.2],
#  ['CQI-11', 776343.2],
#  ['CQI-11', 776616.2],
#  ['IATF', 774005.2],
#  ['AMEF', 774005.2],
#  ['SPC', 774005.2],
#  ['MSA', 774005.2],
#  ['PPAP', 774005.2],
#  ['DG&T', 764692.2],
#  ['DG&T', 774005.2],
#  ['CQI-8', 764692.2],
#  ['CQI-8', 774005.2],
#  ['CQI-9', 774005.2],
#  ['CQI-11', 774005.2],
#  ['CQI-12', 774005.2],
#  ['CQI-15', 774005.2],
#  ['CQI-20', 764692.2],
#  ['CQI-20', 774005.2],
#  ['IATF', 764692.2],
#  ['IATF', 774005.2],
#  ['Instructores', 774005.2],
#  ['Core Tools', 764692.2],
#  ['Core Tools', 774005.2],
#  ['VDA', 764692.2],
#  ['VDA', 774005.2],
#  ['VDA', 764692.2],
#  ['VDA', 774005.2],
#  ['VDA', 764692.2],
#  ['VDA', 774005.2],
#  ['PFMEA', 772754.2],
#  ['IATF', 772754.2],
#  ['SPC', 772754.2],
#  ['equipos_de_medición', 772754.2],
#  ['VDA', 772754.2],
#  ['Administracion de recursos', 770479.2],
#  ['Administracion de recursos', 770120.2],
#  ['Administracion de recursos', 763672.2],
#  ['Administracion de recursos', 861202.2],
#  ['Core Tools', 776532.2],
#  ['Core Tools', 770120.2],
#  ['Core Tools', 763354.2],
#  ['Core Tools', 775239.2],
#  ['Core Tools', 771242.2],
#  ['Core Tools', 763672.2],
#  ['Core Tools', 761543.2],
#  ['Core Tools', 861202.2],
#  ['8 DS', 776532.2],
#  ['8 DS', 770479.2],
#  ['8 DS', 770120.2],
#  ['8 DS', 763672.2],
#  ['8 DS', 861202.2],
#  ['Uso de Portales de Clientes', 776532.2],
#  ['Uso de Portales de Clientes', 770479.2],
#  ['Uso de Portales de Clientes', 763672.2],
#  ['Uso de Portales de Clientes', 761543.2],
#  ['IATF', 776532.2],
#  ['IATF', 770479.2],
#  ['IATF', 770120.2],
#  ['IATF', 763354.2],
#  ['IATF', 775239.2],
#  ['IATF', 771242.2],
#  ['IATF', 763672.2],
#  ['IATF', 761543.2],
#  ['IATF', 861202.2],
#  ['14001', 776532.2],
#  ['14001', 770479.2],
#  ['14001', 770120.2],
#  ['14001', 763354.2],
#  ['14001', 775239.2],
#  ['14001', 771242.2],
#  ['14001', 763672.2],
#  ['14001', 761543.2],
#  ['14001', 861202.2],
#  ['Sigma', 776532.2],
#  ['Sigma', 770479.2],
#  ['Sigma', 770120.2],
#  ['Sigma', 763354.2],
#  ['Sigma', 775239.2],
#  ['Sigma', 771242.2],
#  ['Sigma', 763672.2],
#  ['Sigma', 761543.2],
#  ['Sigma', 861202.2],
#  ['VDA', 776532.2],
#  ['VDA', 770479.2],
#  ['VDA', 763354.2],
#  ['VDA', 761543.2],
#  ['VDA', 861202.2],
#  ['SGC', 776532.2],
#  ['SGC', 770479.2],
#  ['SGC', 763354.2],
#  ['SGC', 775239.2],
#  ['SGC', 771242.2],
#  ['SGC', 763672.2],
#  ['SGC', 861202.2],
#  ['Ingles', 776532.2],
#  ['Ingles', 770120.2],
#  ['Ingles', 763354.2],
#  ['Ingles', 763672.2],
#  ['Ingles', 761543.2],
#  ['Ingles', 861202.2],
#  ['Aston-G', 776532.2],
#  ['Aston-G', 775239.2],
#  ['Aston-G', 771242.2],
#  ['GQUICS', 776532.2],
#  ['GQUICS', 775239.2],
#  ['GQUICS', 771242.2],
#  ['GQUICS', 763672.2],
#  ['CSF Stellantis', 776532.2],
#  ['CSF Stellantis', 770479.2],
#  ['CSF Stellantis', 770120.2],
#  ['CSF Stellantis', 763354.2],
#  ['CSF Stellantis', 775239.2],
#  ['CSF Stellantis', 771242.2],
#  ['CSF Stellantis', 763672.2],
#  ['CSF Stellantis', 761543.2],
#  ['CSF Stellantis', 861202.2],
#  ['CSF Nissan', 776532.2],
#  ['CSF Nissan', 770479.2],
#  ['CSF Nissan', 770120.2],
#  ['CSF Nissan', 763354.2],
#  ['CSF Nissan', 775239.2],
#  ['CSF Nissan', 771242.2],
#  ['CSF Nissan', 763672.2],
#  ['CSF Nissan', 761543.2],
#  ['CSF Nissan', 861202.2],
#  ['CSR Mazda', 776532.2],
#  ['CSR Mazda', 770479.2],
#  ['CSR Mazda', 770120.2],
#  ['CSR Mazda', 763354.2],
#  ['CSR Mazda', 775239.2],
#  ['CSR Mazda', 771242.2],
#  ['CSR Mazda', 763672.2],
#  ['CSR Mazda', 761543.2],
#  ['CSR Mazda', 861202.2],
#  ['CSR Ford', 776532.2],
#  ['CSR Ford', 770479.2],
#  ['CSR Ford', 770120.2],
#  ['CSR Ford', 763354.2],
#  ['CSR Ford', 775239.2],
#  ['CSR Ford', 771242.2],
#  ['CSR Ford', 763672.2],
#  ['CSR Ford', 761543.2],
#  ['CSR Ford', 861202.2],
#  ['CSF Toyota', 776532.2],
#  ['CSF Toyota', 770479.2],
#  ['CSF Toyota', 770120.2],
#  ['CSF Toyota', 763354.2],
#  ['CSF Toyota', 775239.2],
#  ['CSF Toyota', 771242.2],
#  ['CSF Toyota', 763672.2],
#  ['CSF Toyota', 761543.2],
#  ['CSF Toyota', 861202.2],
#  ['Ingles', 1532876.2],
#  ['Ingles', 1542899.2],
#  ['Ingles', 1543365.2],
#  ['Control inventarios', 1542899.2],
#  ['Control inventarios', 1543240.2],
#  ['Excel', 1532876.2],
#  ['Excel', 1542899.2],
#  ['Excel', 1543365.2],
#  ['Presupuestación_y_Control_de_Costos', 1532876.2],
#  ['Presupuestación_y_Control_de_Costos', 1542899.2],
#  ['Presupuestación_y_Control_de_Costos', 1543365.2],
#  ['Presupuestación_y_Control_de_Costos', 1543240.2],
#  ['SPC', 1532876.2],
#  ['SPC', 1542899.2],
#  ['SPC', 1543365.2],
#  ['SPC', 1543240.2],
#  ['InterpretaciónM', 761825.2],
#  ['InterpretaciónM', 767681.2],
#  ['InterpretaciónM', 770437.2],
#  ['InterpretaciónM', 769424.2],
#  ['InterpretaciónM', 764646.2],
#  ['InterpretaciónM', 776263.2],
#  ['InterpretaciónM', 772250.2],
#  ['InterpretaciónM', 776324.2],
#  ['SPC', 761825.2],
#  ['SPC', 767681.2],
#  ['SPC', 770437.2],
#  ['SPC', 769424.2],
#  ['SPC', 764646.2],
#  ['SPC', 776263.2],
#  ['SPC', 772250.2],
#  ['SPC', 776324.2],
#  ['equipos_de_medición', 761825.2],
#  ['equipos_de_medición', 767681.2],
#  ['equipos_de_medición', 770437.2],
#  ['equipos_de_medición', 769424.2],
#  ['equipos_de_medición', 764646.2],
#  ['equipos_de_medición', 776263.2],
#  ['equipos_de_medición', 772250.2],
#  ['equipos_de_medición', 776324.2],
#  ['CQI-12', 761825.2],
#  ['CQI-12', 767681.2],
#  ['CQI-12', 770437.2],
#  ['CQI-12', 769424.2],
#  ['CQI-12', 764646.2],
#  ['CQI-12', 776263.2],
#  ['CQI-12', 772250.2],
#  ['CQI-12', 776324.2],
#  ['CQI-15', 761825.2],
#  ['CQI-15', 767681.2],
#  ['CQI-15', 770437.2],
#  ['CQI-15', 769424.2],
#  ['CQI-15', 764646.2],
#  ['CQI-15', 776263.2],
#  ['CQI-15', 772250.2],
#  ['CQI-15', 776324.2],
#  ['alturas', 761398.2],
#  ['alturas', 765296.2],
#  ['alturas', 772080.2],
#  ['alturas', 773501.2],
#  ['alturas', 768773.2],
#  ['alturas', 770576.2],
#  ['alturas', 773009.2],
#  ['electricidad', 761398.2],
#  ['electricidad', 765296.2],
#  ['electricidad', 773501.2],
#  ['electricidad', 768773.2],
#  ['electricidad', 770576.2],
#  ['electricidad', 773009.2],
#  ['emergencia', 761398.2],
#  ['emergencia', 765296.2],
#  ['emergencia', 772080.2],
#  ['emergencia', 773501.2],
#  ['emergencia', 768773.2],
#  ['emergencia', 770576.2],
#  ['emergencia', 773009.2],
#  ['Soldadura', 761398.2],
#  ['Soldadura', 765296.2],
#  ['Soldadura', 772080.2],
#  ['Soldadura', 773501.2],
#  ['Soldadura', 768773.2],
#  ['Soldadura', 770576.2],
#  ['Soldadura', 773009.2],
#  ['STPS', 774041.2],
#  ['STPS', 774152.2],
#  ['electricidad', 774041.2],
#  ['montacargas', 774041.2],
#  ['montacargas', 774152.2],
#  ['sustancias', 774041.2],
#  ['sustancias', 774152.2],
#  ['NOM_2', 774041.2],
#  ['NOM_2', 774152.2],
#  ['emergencia', 774041.2],
#  ['emergencia', 774152.2],
#  ['alturas', 774152.2],
#  ['8 DS', 761456.2],
#  ['8 DS', 761988.2],
#  ['8 DS', 765144.2],
#  ['8 DS', 771167.2],
#  ['PLC_HMI', 761456.2],
#  ['PLC_HMI', 761988.2],
#  ['PLC_HMI', 765144.2],
#  ['PLC_HMI', 771167.2],
#  ['hidraulica_neumatica_mecanica', 761456.2],
#  ['hidraulica_neumatica_mecanica', 761988.2],
#  ['hidraulica_neumatica_mecanica', 765144.2],
#  ['hidraulica_neumatica_mecanica', 771167.2],
#  ['hidraulica_neumatica_mecanica', 761456.2],
#  ['hidraulica_neumatica_mecanica', 765144.2],
#  ['hidraulica_neumatica_mecanica', 771167.2],
#  ['PLC_HMI', 762040.2],
#  ['PLC_HMI', 762967.2],
#  ['PLC_HMI', 763880.2],
#  ['PLC_HMI', 767805.2],
#  ['PLC_HMI', 772381.2],
#  ['PLC_HMI', 773637.2],
#  ['hidraulica_neumatica_mecanica', 762040.2],
#  ['hidraulica_neumatica_mecanica', 762967.2],
#  ['hidraulica_neumatica_mecanica', 763880.2],
#  ['hidraulica_neumatica_mecanica', 767805.2],
#  ['hidraulica_neumatica_mecanica', 772381.2],
#  ['hidraulica_neumatica_mecanica', 773637.2],
#  ['hidraulica_neumatica_mecanica', 762040.2],
#  ['hidraulica_neumatica_mecanica', 762967.2],
#  ['hidraulica_neumatica_mecanica', 763880.2],
#  ['hidraulica_neumatica_mecanica', 767805.2],
#  ['hidraulica_neumatica_mecanica', 772381.2],
#  ['hidraulica_neumatica_mecanica', 773637.2],
#  ['montacargas', 762040.2],
#  ['montacargas', 762967.2],
#  ['montacargas', 763880.2],
#  ['montacargas', 767805.2],
#  ['montacargas', 772381.2],
#  ['montacargas', 773637.2],
#  ['Panasonic', 762040.2],
#  ['Panasonic', 762967.2],
#  ['Panasonic', 763880.2],
#  ['Panasonic', 767805.2],
#  ['Panasonic', 772381.2],
#  ['Panasonic', 773637.2],
#  ['FANUC', 762040.2],
#  ['FANUC', 762967.2],
#  ['FANUC', 763880.2],
#  ['FANUC', 767805.2],
#  ['FANUC', 772381.2],
#  ['FANUC', 773637.2],
#  ['FANUC', 762040.2],
#  ['FANUC', 762967.2],
#  ['FANUC', 763880.2],
#  ['FANUC', 767805.2],
#  ['FANUC', 772381.2],
#  ['FANUC', 773637.2],
#  ['PLC_HMI', 761736.2],
#  ['PLC_HMI', 764897.2],
#  ['PLC_HMI', 772120.2],
#  ['hidraulica_neumatica_mecanica', 761736.2],
#  ['hidraulica_neumatica_mecanica', 764897.2],
#  ['hidraulica_neumatica_mecanica', 772120.2],
#  ['hidraulica_neumatica_mecanica', 761736.2],
#  ['hidraulica_neumatica_mecanica', 764897.2],
#  ['hidraulica_neumatica_mecanica', 772120.2],
#  ['montacargas', 761736.2],
#  ['montacargas', 764897.2],
#  ['montacargas', 772120.2],
#  ['FANUC', 761736.2],
#  ['FANUC', 764897.2],
#  ['FANUC', 772120.2],
#  ['PLC_HMI', 761621.2],
#  ['PLC_HMI', 764448.2],
#  ['PLC_HMI', 766223.2],
#  ['PLC_HMI', 772849.2],
#  ['PLC_HMI', 773638.2],
#  ['PLC_HMI', 774937.2],
#  ['hidraulica_neumatica_mecanica', 761621.2],
#  ['hidraulica_neumatica_mecanica', 764448.2],
#  ['hidraulica_neumatica_mecanica', 766223.2],
#  ['hidraulica_neumatica_mecanica', 772849.2],
#  ['hidraulica_neumatica_mecanica', 773638.2],
#  ['hidraulica_neumatica_mecanica', 774937.2],
#  ['hidraulica_neumatica_mecanica', 761621.2],
#  ['hidraulica_neumatica_mecanica', 764448.2],
#  ['hidraulica_neumatica_mecanica', 766223.2],
#  ['hidraulica_neumatica_mecanica', 772849.2],
#  ['hidraulica_neumatica_mecanica', 773638.2],
#  ['hidraulica_neumatica_mecanica', 774937.2],
#  ['Denso', 761621.2],
#  ['Denso', 764448.2],
#  ['Denso', 766223.2],
#  ['Absodex', 761621.2],
#  ['Absodex', 764448.2],
#  ['Absodex', 766223.2],
#  ['Absodex', 772849.2],
#  ['Absodex', 773638.2],
#  ['Absodex', 774937.2],
#  ['IAI_Yamaha', 772849.2],
#  ['PLC_HMI', 761769.2],
#  ['PLC_HMI', 767655.2],
#  ['PLC_HMI', 768659.2],
#  ['PLC_HMI', 770895.2],
#  ['PLC_HMI', 775445.2],
#  ['hidraulica_neumatica_mecanica', 761769.2],
#  ['hidraulica_neumatica_mecanica', 767655.2],
#  ['hidraulica_neumatica_mecanica', 768659.2],
#  ['hidraulica_neumatica_mecanica', 770895.2],
#  ['hidraulica_neumatica_mecanica', 775445.2],
#  ['hidraulica_neumatica_mecanica', 761769.2],
#  ['hidraulica_neumatica_mecanica', 767655.2],
#  ['hidraulica_neumatica_mecanica', 768659.2],
#  ['hidraulica_neumatica_mecanica', 770895.2],
#  ['hidraulica_neumatica_mecanica', 775445.2],
#  ['montacargas', 761769.2],
#  ['montacargas', 767655.2],
#  ['montacargas', 768659.2],
#  ['montacargas', 770895.2],
#  ['montacargas', 775445.2],
#  ['alturas', 761769.2],
#  ['alturas', 767655.2],
#  ['alturas', 768659.2],
#  ['alturas', 770895.2],
#  ['alturas', 775445.2],
#  ['confinado', 761769.2],
#  ['confinado', 767655.2],
#  ['confinado', 768659.2],
#  ['confinado', 770895.2],
#  ['confinado', 775445.2],
#  ['sustancias', 761769.2],
#  ['sustancias', 767655.2],
#  ['sustancias', 768659.2],
#  ['sustancias', 770895.2],
#  ['sustancias', 775445.2],
#  ['KUKA', 767655.2],
#  ['KUKA', 770895.2],
#  ['KUKA', 775445.2],
#  ['Ingles', 769860.2],
#  ['Ingles', 770288.2],
#  ['Ingles', 773186.2],
#  ['Ingles', 776476.2],
#  ['autocad', 776546.2],
#  ['Uso de Portales de Clientes', 769860.2],
#  ['Uso de Portales de Clientes', 773186.2],
#  ['Uso de Portales de Clientes', 776476.2],
#  ['Uso de Portales de Clientes', 776546.2],
#  ['Sigma', 769860.2],
#  ['Sigma', 770288.2],
#  ['Sigma', 773186.2],
#  ['Sigma', 776476.2],
#  ['Core Tools', 770288.2],
#  ['Core Tools', 773186.2],
#  ['8 DS', 769860.2],
#  ['8 DS', 770288.2],
#  ['8 DS', 773186.2],
#  ['8 DS', 776476.2],
#  ['8 DS', 776546.2],
#  ['vsm mixel model', 769860.2],
#  ['vsm mixel model', 770288.2],
#  ['vsm mixel model', 773186.2],
#  ['vsm mixel model', 776476.2],
#  ['vsm mixel model', 776546.2],
#  ['IATF', 770288.2],
#  ['IATF', 773186.2],
#  ['IATF', 776476.2],
#  ['creating level pull', 769860.2],
#  ['creating level pull', 770288.2],
#  ['creating level pull', 773186.2],
#  ['creating level pull', 776476.2],
#  ['creating level pull', 776546.2],
#  ['LOTO', 761371.2],
#  ['LOTO', 761575.2],
#  ['LOTO', 769347.2],
#  ['LOTO', 771084.2],
#  ['LOTO', 772254.2],
#  ['LOTO', 772361.2],
#  ['LOTO', 776224.2],
#  ['termografia', 761371.2],
#  ['termografia', 761575.2],
#  ['termografia', 769347.2],
#  ['termografia', 771084.2],
#  ['termografia', 772254.2],
#  ['termografia', 772361.2],
#  ['termografia', 776224.2],
#  ['CQI-9', 761371.2],
#  ['CQI-9', 761575.2],
#  ['CQI-9', 769347.2],
#  ['CQI-9', 771084.2],
#  ['CQI-9', 772254.2],
#  ['CQI-9', 772361.2],
#  ['CQI-9', 776224.2],
#  ['CQI-11', 761371.2],
#  ['CQI-11', 761575.2],
#  ['CQI-11', 769347.2],
#  ['CQI-11', 771084.2],
#  ['CQI-11', 772254.2],
#  ['CQI-11', 772361.2],
#  ['CQI-11', 776224.2],
#  ['CQI-12', 761371.2],
#  ['CQI-12', 761575.2],
#  ['CQI-12', 769347.2],
#  ['CQI-12', 771084.2],
#  ['CQI-12', 772254.2],
#  ['CQI-12', 772361.2],
#  ['CQI-12', 776224.2],
#  ['ComercioE', 1543309.2],
#  ['ComercioE', 1530519.2],
#  ['calculo de valor de contenido regional', 1543309.2],
#  ['calculo de valor de contenido regional', 1530519.2],
#  ['auditorias electronicas y fiscalizacion', 1543309.2],
#  ['auditorias electronicas y fiscalizacion', 1530519.2],
#  ['auditorias de activo fijo: parametros para tener una correcta administracion de la maquinaria y equipo.',
#   1543309.2],
#  ['auditorias de activo fijo: parametros para tener una correcta administracion de la maquinaria y equipo.',
#   1530519.2],
#  ['Correcto_analisis', 1543309.2],
#  ['Correcto_analisis', 1530519.2],
#  ['CTPAT & OEA', 1543309.2],
#  ['CTPAT & OEA', 1530519.2],
#  ['immex', 1543309.2],
#  ['immex', 1530519.2],
#  ['CAMPA', 1543309.2],
#  ['CAMPA', 1530519.2],
#  ['anexo 24', 1543309.2],
#  ['anexo 24', 1530519.2],
#  ['aduanal', 1543309.2],
#  ['aduanal', 1530519.2],
#  ['ISO 31000', 764692.2],
#  ['ISO 31000', 774005.2],
#  ['ISO 31000', 774232.2],
#  ['ISO 31000', 774268.2],
#  ['ISO 31000', 769466.2],
#  ['ISO 31000', 773190.2],
#  ['ISO 31000', 776169.2],
#  ['ISO 31000', 767806.2],
#  ['ISO 31000', 775425.2],
#  ['ISO 31000', 769987.2],
#  ['ISO 31000', 766535.2],
#  ['ISO 31000', 771174.2],
#  ['ISO 31000', 761525.2],
#  ['ISO 31000', 772845.2],
#  ['ISO 31000', 770784.2],
#  ['ISO 31000', 765240.2],
#  ['ISO 31000', 773641.2],
#  ['ISO 31000', 769466.5],
#  ['ISO 31000', 771109.2],
#  ['ISO 31000', 776476.2],
#  ['ISO 31000', 773486.2],
#  ['ISO 31000', 770288.2],
#  ['ISO 31000', 774022.2],
#  ['ISO 31000', 764880.2],
#  ['ISO 31000', 774231.2],
#  ['ISO 31000', 763354.2],
#  ['ISO 31000', 770120.2],
#  ['ISO 31000', 771242.2],
#  ['ISO 31000', 761206.2],
#  ['ISO 31000', 761268.2],
#  ['ISO 31000', 763672.2],
#  ['ISO 31000', 761543.2],
#  ['ISO 31000', 773751.2],
#  ['ISO 31000', 770183.2],
#  ['ISO 31000', 770288.5],
#  ['ISO 9000', 774005.2],
#  ['ISO 9000', 774232.2],
#  ['ISO 9000', 774268.2],
#  ['ISO 9000', 769466.2],
#  ['ISO 9000', 773190.2],
#  ['ISO 9000', 776169.2],
#  ['ISO 9000', 767806.2],
#  ['ISO 9000', 775425.2],
#  ['ISO 9000', 769987.2],
#  ['ISO 9000', 766535.2],
#  ['ISO 9000', 771174.2],
#  ['ISO 9000', 761525.2],
#  ['ISO 9000', 772845.2],
#  ['ISO 9000', 770784.2],
#  ['ISO 9000', 765240.2],
#  ['ISO 9000', 773641.2],
#  ['ISO 9000', 769466.5],
#  ['ISO 9000', 771109.2],
#  ['ISO 9000', 776476.2],
#  ['ISO 9000', 773486.2],
#  ['ISO 9000', 770288.2],
#  ['ISO 9000', 774022.2],
#  ['ISO 9000', 764880.2],
#  ['ISO 9000', 774231.2],
#  ['ISO 9000', 763354.2],
#  ['ISO 9000', 770120.2],
#  ['ISO 9000', 771242.2],
#  ['ISO 9000', 761206.2],
#  ['ISO 9000', 761268.2],
#  ['ISO 9000', 763672.2],
#  ['ISO 9000', 761543.2],
#  ['ISO 9000', 773751.2],
#  ['ISO 9000', 770183.2],
#  ['ISO 9000', 770288.5],
#  ['ISO 19011', 774232.2],
#  ['ISO 19011', 774268.2],
#  ['ISO 19011', 773190.2],
#  ['ISO 19011', 776169.2],
#  ['ISO 19011', 767806.2],
#  ['ISO 19011', 775425.2],
#  ['ISO 19011', 769987.2],
#  ['ISO 19011', 766535.2],
#  ['ISO 19011', 771174.2],
#  ['ISO 19011', 761525.2],
#  ['ISO 19011', 772845.2],
#  ['ISO 19011', 770784.2],
#  ['ISO 19011', 765240.2],
#  ['ISO 19011', 773641.2],
#  ['ISO 19011', 771109.2],
#  ['ISO 19011', 776476.2],
#  ['ISO 19011', 773486.2],
#  ['ISO 19011', 770288.2],
#  ['ISO 19011', 774022.2],
#  ['ISO 19011', 764880.2],
#  ['ISO 19011', 774231.2],
#  ['ISO 19011', 763354.2],
#  ['ISO 19011', 761543.2],
#  ['ISO 19011', 773751.2],
#  ['ISO 19011', 770183.2],
#  ['ISO 19011', 770288.5],
#  ['ISO 9001', 774232.2],
#  ['ISO 9001', 774268.2],
#  ['ISO 9001', 773190.2],
#  ['ISO 9001', 776169.2],
#  ['ISO 9001', 767806.2],
#  ['ISO 9001', 775425.2],
#  ['ISO 9001', 769987.2],
#  ['ISO 9001', 766535.2],
#  ['ISO 9001', 771174.2],
#  ['ISO 9001', 761525.2],
#  ['ISO 9001', 772845.2],
#  ['ISO 9001', 770784.2],
#  ['ISO 9001', 765240.2],
#  ['ISO 9001', 773641.2],
#  ['ISO 9001', 771109.2],
#  ['ISO 9001', 776476.2],
#  ['ISO 9001', 773486.2],
#  ['ISO 9001', 770288.2],
#  ['ISO 9001', 774022.2],
#  ['ISO 9001', 764880.2],
#  ['ISO 9001', 774231.2],
#  ['ISO 9001', 763354.2],
#  ['ISO 9001', 771242.2],
#  ['ISO 9001', 761543.2],
#  ['ISO 9001', 773751.2],
#  ['ISO 9001', 770183.2],
#  ['ISO 9001', 770288.5],
#  ['IATF', 774232.2],
#  ['IATF', 774268.2],
#  ['IATF', 773190.2],
#  ['IATF', 776169.2],
#  ['IATF', 767806.2],
#  ['IATF', 775425.2],
#  ['IATF', 769987.2],
#  ['IATF', 766535.2],
#  ['IATF', 771174.2],
#  ['IATF', 761525.2],
#  ['IATF', 772845.2],
#  ['IATF', 770784.2],
#  ['IATF', 765240.2],
#  ['IATF', 773641.2],
#  ['IATF', 769466.5],
#  ['IATF', 771109.2],
#  ['IATF', 776476.2],
#  ['IATF', 773486.2],
#  ['IATF', 770288.2],
#  ['IATF', 774022.2],
#  ['IATF', 764880.2],
#  ['IATF', 774231.2],
#  ['IATF', 763354.2],
#  ['IATF', 761543.2],
#  ['IATF', 773751.2],
#  ['IATF', 770183.2],
#  ['IATF', 770288.5],
#  ['8 DS', 774232.2],
#  ['8 DS', 774268.2],
#  ['8 DS', 769466.2],
#  ['8 DS', 773190.2],
#  ['8 DS', 767806.2],
#  ['8 DS', 775425.2],
#  ['8 DS', 769987.2],
#  ['8 DS', 766535.2],
#  ['8 DS', 771174.2],
#  ['8 DS', 761525.2],
#  ['8 DS', 772845.2],
#  ['8 DS', 770784.2],
#  ['8 DS', 765240.2],
#  ['8 DS', 773641.2],
#  ['8 DS', 769466.5],
#  ['8 DS', 771109.2],
#  ['8 DS', 776476.2],
#  ['8 DS', 773486.2],
#  ['8 DS', 770288.2],
#  ['8 DS', 774022.2],
#  ['8 DS', 764880.2],
#  ['8 DS', 774231.2],
#  ['8 DS', 763354.2],
#  ['8 DS', 771242.2],
#  ['8 DS', 761206.2],
#  ['8 DS', 761268.2],
#  ['8 DS', 763672.2],
#  ['8 DS', 761543.2],
#  ['8 DS', 773751.2],
#  ['8 DS', 770183.2],
#  ['8 DS', 770288.5],
#  ['Core Tools', 774005.2],
#  ['Core Tools', 774232.2],
#  ['Core Tools', 774268.2],
#  ['Core Tools', 769466.2],
#  ['Core Tools', 773190.2],
#  ['Core Tools', 776169.2],
#  ['Core Tools', 767806.2],
#  ['Core Tools', 775425.2],
#  ['Core Tools', 769987.2],
#  ['Core Tools', 766535.2],
#  ['Core Tools', 771174.2],
#  ['Core Tools', 761525.2],
#  ['Core Tools', 772845.2],
#  ['Core Tools', 770784.2],
#  ['Core Tools', 765240.2],
#  ['Core Tools', 773641.2],
#  ['Core Tools', 769466.5],
#  ['Core Tools', 771109.2],
#  ['Core Tools', 776476.2],
#  ['Core Tools', 773486.2],
#  ['Core Tools', 770288.2],
#  ['Core Tools', 774022.2],
#  ['Core Tools', 764880.2],
#  ['Core Tools', 774231.2],
#  ['Core Tools', 763354.2],
#  ['Core Tools', 770120.2],
#  ['Core Tools', 761206.2],
#  ['Core Tools', 761268.2],
#  ['Core Tools', 763672.2],
#  ['Core Tools', 761543.2],
#  ['Core Tools', 773751.2],
#  ['Core Tools', 770183.2],
#  ['Core Tools', 770288.5],
#  ['APQP', 774268.2],
#  ['APQP', 769466.2],
#  ['APQP', 773190.2],
#  ['APQP', 776169.2],
#  ['APQP', 767806.2],
#  ['APQP', 775425.2],
#  ['APQP', 769987.2],
#  ['APQP', 766535.2],
#  ['APQP', 771174.2],
#  ['APQP', 761525.2],
#  ['APQP', 772845.2],
#  ['APQP', 770784.2],
#  ['APQP', 765240.2],
#  ...]

# %%
# Convertir los valores flotantes a enteros
nominas = [[nombre, int(valor)] for nombre, valor in nominas]

# %%
nominas
# Out:
# [['AMEF', 773143],
#  ['AMEF', 765736],
#  ['AMEF', 776477],
#  ['AMEF', 761870],
#  ['AMEF', 764984],
#  ['AMEF', 773752],
#  ['AMEF', 776206],
#  ['AMEF', 773751],
#  ['Entendimiento de Plan de Control', 773143],
#  ['Entendimiento de Plan de Control', 765736],
#  ['Entendimiento de Plan de Control', 776477],
#  ['Entendimiento de Plan de Control', 761870],
#  ['Entendimiento de Plan de Control', 764984],
#  ['Entendimiento de Plan de Control', 773752],
#  ['Entendimiento de Plan de Control', 776206],
#  ['Entendimiento de Plan de Control', 773751],
#  ['IATF', 776477],
#  ['IATF', 761870],
#  ['IATF', 773752],
#  ['IATF', 776206],
#  ['IATF', 773751],
#  ['SPC', 773143],
#  ['SPC', 765736],
#  ['SPC', 776477],
#  ['SPC', 761870],
#  ['SPC', 764984],
#  ['SPC', 773752],
#  ['SPC', 776206],
#  ['SPC', 773751],
#  ['ILUO', 773752],
#  ['ILUO', 776206],
#  ['ILUO', 773751],
#  ['8 DS', 773143],
#  ['8 DS', 765736],
#  ['8 DS', 776477],
#  ['8 DS', 761870],
#  ['8 DS', 764984],
#  ['8 DS', 773752],
#  ['8 DS', 776206],
#  ['8 DS', 773751],
#  ['apqp (planificacion avanzada del producto)', 773143],
#  ['apqp (planificacion avanzada del producto)', 765736],
#  ['apqp (planificacion avanzada del producto)', 776477],
#  ['apqp (planificacion avanzada del producto)', 761870],
#  ['apqp (planificacion avanzada del producto)', 764984],
#  ['apqp (planificacion avanzada del producto)', 773752],
#  ['apqp (planificacion avanzada del producto)', 776206],
#  ['apqp (planificacion avanzada del producto)', 773751],
#  ['MSA', 773143],
#  ['MSA', 765736],
#  ['MSA', 776477],
#  ['MSA', 761870],
#  ['MSA', 764984],
#  ['MSA', 773752],
#  ['MSA', 776206],
#  ['MSA', 773751],
#  ['ppap', 773143],
#  ['ppap', 765736],
#  ['ppap', 776477],
#  ['ppap', 761870],
#  ['ppap', 764984],
#  ['ppap', 773752],
#  ['ppap', 776206],
#  ['ppap', 773751],
#  ['CRS (Requerimientos Especificos del Cliente)', 773143],
#  ['CRS (Requerimientos Especificos del Cliente)', 765736],
#  ['CRS (Requerimientos Especificos del Cliente)', 776477],
#  ['CRS (Requerimientos Especificos del Cliente)', 761870],
#  ['CRS (Requerimientos Especificos del Cliente)', 764984],
#  ['CRS (Requerimientos Especificos del Cliente)', 773752],
#  ['CRS (Requerimientos Especificos del Cliente)', 776206],
#  ['CRS (Requerimientos Especificos del Cliente)', 773751],
#  ['VDA', 773143],
#  ['VDA', 765736],
#  ['VDA', 776477],
#  ['VDA', 761870],
#  ['VDA', 764984],
#  ['VDA', 773752],
#  ['VDA', 776206],
#  ['VDA', 773751],
#  ['PLC_HMI', 767089],
#  ['PLC_HMI', 769547],
#  ['PLC_HMI', 770928],
#  ['PLC_HMI', 771697],
#  ['PLC_HMI', 772164],
#  ['PLC_HMI', 767089],
#  ['PLC_HMI', 769547],
#  ['PLC_HMI', 770928],
#  ['PLC_HMI', 771697],
#  ['PLC_HMI', 772164],
#  ['camaras', 771697],
#  ['camaras', 772164],
#  ['Panasonic', 767089],
#  ['Panasonic', 769547],
#  ['Panasonic', 770928],
#  ['Panasonic', 771697],
#  ['Panasonic', 772164],
#  ['Denso', 767089],
#  ['Denso', 770928],
#  ['Denso', 771697],
#  ['Denso', 772164],
#  ['IAI_Yamaha', 767089],
#  ['IAI_Yamaha', 769547],
#  ['IAI_Yamaha', 770928],
#  ['IAI_Yamaha', 771697],
#  ['IAI_Yamaha', 772164],
#  ['LOTO', 767089],
#  ['LOTO', 769547],
#  ['LOTO', 770928],
#  ['LOTO', 771697],
#  ['LOTO', 772164],
#  ['Measure Link', 763051],
#  ['Measure Link', 765514],
#  ['Measure Link', 773072],
#  ['Measure Link', 761388],
#  ['Measure Link', 771166],
#  ['Measure Link', 764426],
#  ['Measure Link', 761746],
#  ['Measure Link', 771379],
#  ['Measure Link', 763311],
#  ['Measure Link', 773495],
#  ['Measure Link', 773287],
#  ['Measure Link', 772902],
#  ['Measure Link', 773755],
#  ['Measure Link', 771373],
#  ['Measure Link', 770183],
#  ['Entendimiento de Plan de Control', 763051],
#  ['Entendimiento de Plan de Control', 765514],
#  ['Entendimiento de Plan de Control', 773072],
#  ['Entendimiento de Plan de Control', 761388],
#  ['Entendimiento de Plan de Control', 771166],
#  ['Entendimiento de Plan de Control', 764426],
#  ['Entendimiento de Plan de Control', 761746],
#  ['Entendimiento de Plan de Control', 771379],
#  ['Entendimiento de Plan de Control', 763311],
#  ['Entendimiento de Plan de Control', 773495],
#  ['Entendimiento de Plan de Control', 773287],
#  ['Entendimiento de Plan de Control', 772902],
#  ['Entendimiento de Plan de Control', 773755],
#  ['Entendimiento de Plan de Control', 771373],
#  ['Entendimiento de Plan de Control', 770183],
#  ['IATF', 764426],
#  ['IATF', 761746],
#  ['IATF', 771379],
#  ['IATF', 763311],
#  ['IATF', 773495],
#  ['IATF', 773287],
#  ['IATF', 771373],
#  ['SPC', 763051],
#  ['SPC', 765514],
#  ['SPC', 773072],
#  ['SPC', 761388],
#  ['SPC', 771166],
#  ['SPC', 764426],
#  ['SPC', 761746],
#  ['SPC', 771379],
#  ['SPC', 763311],
#  ['SPC', 773495],
#  ['SPC', 773287],
#  ['SPC', 772902],
#  ['SPC', 773755],
#  ['SPC', 771373],
#  ['SPC', 770183],
#  ['gagetrak', 771166],
#  ['gagetrak', 764426],
#  ['gagetrak', 761746],
#  ['gagetrak', 771379],
#  ['gagetrak', 763311],
#  ['gagetrak', 773495],
#  ['gagetrak', 773287],
#  ['gagetrak', 771373],
#  ['ILUO', 773072],
#  ['ILUO', 764426],
#  ['ILUO', 761746],
#  ['ILUO', 771379],
#  ['ILUO', 763311],
#  ['ILUO', 773495],
#  ['ILUO', 773287],
#  ['ILUO', 771373],
#  ['8 DS', 763051],
#  ['8 DS', 765514],
#  ['8 DS', 773072],
#  ['8 DS', 761388],
#  ['8 DS', 771166],
#  ['8 DS', 764426],
#  ['8 DS', 761746],
#  ['8 DS', 771379],
#  ['8 DS', 763311],
#  ['8 DS', 773495],
#  ['8 DS', 773287],
#  ['8 DS', 772902],
#  ['8 DS', 773755],
#  ['8 DS', 771373],
#  ['DG&T', 763051],
#  ['DG&T', 765514],
#  ['DG&T', 773072],
#  ['DG&T', 761388],
#  ['DG&T', 771166],
#  ['DG&T', 764426],
#  ['DG&T', 761746],
#  ['DG&T', 771379],
#  ['DG&T', 763311],
#  ['DG&T', 773495],
#  ['DG&T', 773287],
#  ['DG&T', 772902],
#  ['DG&T', 773755],
#  ['DG&T', 771373],
#  ['DG&T', 770183],
#  ['equipos_de_medición', 763051],
#  ['equipos_de_medición', 765514],
#  ['equipos_de_medición', 773072],
#  ['equipos_de_medición', 761388],
#  ['equipos_de_medición', 771166],
#  ['equipos_de_medición', 764426],
#  ['equipos_de_medición', 761746],
#  ['equipos_de_medición', 771379],
#  ['equipos_de_medición', 763311],
#  ['equipos_de_medición', 773495],
#  ['equipos_de_medición', 773287],
#  ['equipos_de_medición', 772902],
#  ['equipos_de_medición', 773755],
#  ['equipos_de_medición', 771373],
#  ['equipos_de_medición', 770183],
#  ['Normas metrologia', 763051],
#  ['Normas metrologia', 765514],
#  ['Normas metrologia', 773072],
#  ['Normas metrologia', 761388],
#  ['Normas metrologia', 771166],
#  ['Normas metrologia', 764426],
#  ['Normas metrologia', 761746],
#  ['Normas metrologia', 771379],
#  ['Normas metrologia', 763311],
#  ['Normas metrologia', 773495],
#  ['Normas metrologia', 773287],
#  ['Normas metrologia', 772902],
#  ['Normas metrologia', 773755],
#  ['Normas metrologia', 771373],
#  ['Normas metrologia', 770183],
#  ['CRS (Requerimientos Especificos del Cliente)', 763051],
#  ['CRS (Requerimientos Especificos del Cliente)', 765514],
#  ['CRS (Requerimientos Especificos del Cliente)', 773072],
#  ['CRS (Requerimientos Especificos del Cliente)', 761388],
#  ['CRS (Requerimientos Especificos del Cliente)', 771166],
#  ['CRS (Requerimientos Especificos del Cliente)', 764426],
#  ['CRS (Requerimientos Especificos del Cliente)', 761746],
#  ['CRS (Requerimientos Especificos del Cliente)', 771379],
#  ['CRS (Requerimientos Especificos del Cliente)', 763311],
#  ['CRS (Requerimientos Especificos del Cliente)', 773495],
#  ['CRS (Requerimientos Especificos del Cliente)', 773287],
#  ['CRS (Requerimientos Especificos del Cliente)', 772902],
#  ['CRS (Requerimientos Especificos del Cliente)', 773755],
#  ['CRS (Requerimientos Especificos del Cliente)', 771373],
#  ['CRS (Requerimientos Especificos del Cliente)', 770183],
#  ['VDA', 763051],
#  ['VDA', 765514],
#  ['VDA', 773072],
#  ['VDA', 761388],
#  ['VDA', 771166],
#  ['VDA', 764426],
#  ['VDA', 761746],
#  ['VDA', 771379],
#  ['VDA', 763311],
#  ['VDA', 773495],
#  ['VDA', 773287],
#  ['VDA', 772902],
#  ['VDA', 773755],
#  ['VDA', 771373],
#  ['VDA', 770183],
#  ['InterpretaciónM', 761720],
#  ['InterpretaciónM', 761984],
#  ['InterpretaciónM', 762243],
#  ['InterpretaciónM', 763052],
#  ['InterpretaciónM', 767167],
#  ['InterpretaciónM', 769062],
#  ['InterpretaciónM', 765788],
#  ['InterpretaciónM', 776343],
#  ['InterpretaciónM', 776616],
#  ['SPC', 761720],
#  ['SPC', 761984],
#  ['SPC', 762243],
#  ['SPC', 763052],
#  ['SPC', 767167],
#  ['SPC', 769062],
#  ['SPC', 765788],
#  ['SPC', 776343],
#  ['SPC', 776616],
#  ['termicos', 761720],
#  ['termicos', 761984],
#  ['termicos', 762243],
#  ['termicos', 763052],
#  ['termicos', 767167],
#  ['termicos', 769062],
#  ['termicos', 765788],
#  ['termicos', 776343],
#  ['termicos', 776616],
#  ['CQI-11', 761720],
#  ['CQI-11', 761984],
#  ['CQI-11', 762243],
#  ['CQI-11', 763052],
#  ['CQI-11', 767167],
#  ['CQI-11', 769062],
#  ['CQI-11', 765788],
#  ['CQI-11', 776343],
#  ['CQI-11', 776616],
#  ['IATF', 774005],
#  ['AMEF', 774005],
#  ['SPC', 774005],
#  ['MSA', 774005],
#  ['PPAP', 774005],
#  ['DG&T', 764692],
#  ['DG&T', 774005],
#  ['CQI-8', 764692],
#  ['CQI-8', 774005],
#  ['CQI-9', 774005],
#  ['CQI-11', 774005],
#  ['CQI-12', 774005],
#  ['CQI-15', 774005],
#  ['CQI-20', 764692],
#  ['CQI-20', 774005],
#  ['IATF', 764692],
#  ['IATF', 774005],
#  ['Instructores', 774005],
#  ['Core Tools', 764692],
#  ['Core Tools', 774005],
#  ['VDA', 764692],
#  ['VDA', 774005],
#  ['VDA', 764692],
#  ['VDA', 774005],
#  ['VDA', 764692],
#  ['VDA', 774005],
#  ['PFMEA', 772754],
#  ['IATF', 772754],
#  ['SPC', 772754],
#  ['equipos_de_medición', 772754],
#  ['VDA', 772754],
#  ['Administracion de recursos', 770479],
#  ['Administracion de recursos', 770120],
#  ['Administracion de recursos', 763672],
#  ['Administracion de recursos', 861202],
#  ['Core Tools', 776532],
#  ['Core Tools', 770120],
#  ['Core Tools', 763354],
#  ['Core Tools', 775239],
#  ['Core Tools', 771242],
#  ['Core Tools', 763672],
#  ['Core Tools', 761543],
#  ['Core Tools', 861202],
#  ['8 DS', 776532],
#  ['8 DS', 770479],
#  ['8 DS', 770120],
#  ['8 DS', 763672],
#  ['8 DS', 861202],
#  ['Uso de Portales de Clientes', 776532],
#  ['Uso de Portales de Clientes', 770479],
#  ['Uso de Portales de Clientes', 763672],
#  ['Uso de Portales de Clientes', 761543],
#  ['IATF', 776532],
#  ['IATF', 770479],
#  ['IATF', 770120],
#  ['IATF', 763354],
#  ['IATF', 775239],
#  ['IATF', 771242],
#  ['IATF', 763672],
#  ['IATF', 761543],
#  ['IATF', 861202],
#  ['14001', 776532],
#  ['14001', 770479],
#  ['14001', 770120],
#  ['14001', 763354],
#  ['14001', 775239],
#  ['14001', 771242],
#  ['14001', 763672],
#  ['14001', 761543],
#  ['14001', 861202],
#  ['Sigma', 776532],
#  ['Sigma', 770479],
#  ['Sigma', 770120],
#  ['Sigma', 763354],
#  ['Sigma', 775239],
#  ['Sigma', 771242],
#  ['Sigma', 763672],
#  ['Sigma', 761543],
#  ['Sigma', 861202],
#  ['VDA', 776532],
#  ['VDA', 770479],
#  ['VDA', 763354],
#  ['VDA', 761543],
#  ['VDA', 861202],
#  ['SGC', 776532],
#  ['SGC', 770479],
#  ['SGC', 763354],
#  ['SGC', 775239],
#  ['SGC', 771242],
#  ['SGC', 763672],
#  ['SGC', 861202],
#  ['Ingles', 776532],
#  ['Ingles', 770120],
#  ['Ingles', 763354],
#  ['Ingles', 763672],
#  ['Ingles', 761543],
#  ['Ingles', 861202],
#  ['Aston-G', 776532],
#  ['Aston-G', 775239],
#  ['Aston-G', 771242],
#  ['GQUICS', 776532],
#  ['GQUICS', 775239],
#  ['GQUICS', 771242],
#  ['GQUICS', 763672],
#  ['CSF Stellantis', 776532],
#  ['CSF Stellantis', 770479],
#  ['CSF Stellantis', 770120],
#  ['CSF Stellantis', 763354],
#  ['CSF Stellantis', 775239],
#  ['CSF Stellantis', 771242],
#  ['CSF Stellantis', 763672],
#  ['CSF Stellantis', 761543],
#  ['CSF Stellantis', 861202],
#  ['CSF Nissan', 776532],
#  ['CSF Nissan', 770479],
#  ['CSF Nissan', 770120],
#  ['CSF Nissan', 763354],
#  ['CSF Nissan', 775239],
#  ['CSF Nissan', 771242],
#  ['CSF Nissan', 763672],
#  ['CSF Nissan', 761543],
#  ['CSF Nissan', 861202],
#  ['CSR Mazda', 776532],
#  ['CSR Mazda', 770479],
#  ['CSR Mazda', 770120],
#  ['CSR Mazda', 763354],
#  ['CSR Mazda', 775239],
#  ['CSR Mazda', 771242],
#  ['CSR Mazda', 763672],
#  ['CSR Mazda', 761543],
#  ['CSR Mazda', 861202],
#  ['CSR Ford', 776532],
#  ['CSR Ford', 770479],
#  ['CSR Ford', 770120],
#  ['CSR Ford', 763354],
#  ['CSR Ford', 775239],
#  ['CSR Ford', 771242],
#  ['CSR Ford', 763672],
#  ['CSR Ford', 761543],
#  ['CSR Ford', 861202],
#  ['CSF Toyota', 776532],
#  ['CSF Toyota', 770479],
#  ['CSF Toyota', 770120],
#  ['CSF Toyota', 763354],
#  ['CSF Toyota', 775239],
#  ['CSF Toyota', 771242],
#  ['CSF Toyota', 763672],
#  ['CSF Toyota', 761543],
#  ['CSF Toyota', 861202],
#  ['Ingles', 1532876],
#  ['Ingles', 1542899],
#  ['Ingles', 1543365],
#  ['Control inventarios', 1542899],
#  ['Control inventarios', 1543240],
#  ['Excel', 1532876],
#  ['Excel', 1542899],
#  ['Excel', 1543365],
#  ['Presupuestación_y_Control_de_Costos', 1532876],
#  ['Presupuestación_y_Control_de_Costos', 1542899],
#  ['Presupuestación_y_Control_de_Costos', 1543365],
#  ['Presupuestación_y_Control_de_Costos', 1543240],
#  ['SPC', 1532876],
#  ['SPC', 1542899],
#  ['SPC', 1543365],
#  ['SPC', 1543240],
#  ['InterpretaciónM', 761825],
#  ['InterpretaciónM', 767681],
#  ['InterpretaciónM', 770437],
#  ['InterpretaciónM', 769424],
#  ['InterpretaciónM', 764646],
#  ['InterpretaciónM', 776263],
#  ['InterpretaciónM', 772250],
#  ['InterpretaciónM', 776324],
#  ['SPC', 761825],
#  ['SPC', 767681],
#  ['SPC', 770437],
#  ['SPC', 769424],
#  ['SPC', 764646],
#  ['SPC', 776263],
#  ['SPC', 772250],
#  ['SPC', 776324],
#  ['equipos_de_medición', 761825],
#  ['equipos_de_medición', 767681],
#  ['equipos_de_medición', 770437],
#  ['equipos_de_medición', 769424],
#  ['equipos_de_medición', 764646],
#  ['equipos_de_medición', 776263],
#  ['equipos_de_medición', 772250],
#  ['equipos_de_medición', 776324],
#  ['CQI-12', 761825],
#  ['CQI-12', 767681],
#  ['CQI-12', 770437],
#  ['CQI-12', 769424],
#  ['CQI-12', 764646],
#  ['CQI-12', 776263],
#  ['CQI-12', 772250],
#  ['CQI-12', 776324],
#  ['CQI-15', 761825],
#  ['CQI-15', 767681],
#  ['CQI-15', 770437],
#  ['CQI-15', 769424],
#  ['CQI-15', 764646],
#  ['CQI-15', 776263],
#  ['CQI-15', 772250],
#  ['CQI-15', 776324],
#  ['alturas', 761398],
#  ['alturas', 765296],
#  ['alturas', 772080],
#  ['alturas', 773501],
#  ['alturas', 768773],
#  ['alturas', 770576],
#  ['alturas', 773009],
#  ['electricidad', 761398],
#  ['electricidad', 765296],
#  ['electricidad', 773501],
#  ['electricidad', 768773],
#  ['electricidad', 770576],
#  ['electricidad', 773009],
#  ['emergencia', 761398],
#  ['emergencia', 765296],
#  ['emergencia', 772080],
#  ['emergencia', 773501],
#  ['emergencia', 768773],
#  ['emergencia', 770576],
#  ['emergencia', 773009],
#  ['Soldadura', 761398],
#  ['Soldadura', 765296],
#  ['Soldadura', 772080],
#  ['Soldadura', 773501],
#  ['Soldadura', 768773],
#  ['Soldadura', 770576],
#  ['Soldadura', 773009],
#  ['STPS', 774041],
#  ['STPS', 774152],
#  ['electricidad', 774041],
#  ['montacargas', 774041],
#  ['montacargas', 774152],
#  ['sustancias', 774041],
#  ['sustancias', 774152],
#  ['NOM_2', 774041],
#  ['NOM_2', 774152],
#  ['emergencia', 774041],
#  ['emergencia', 774152],
#  ['alturas', 774152],
#  ['8 DS', 761456],
#  ['8 DS', 761988],
#  ['8 DS', 765144],
#  ['8 DS', 771167],
#  ['PLC_HMI', 761456],
#  ['PLC_HMI', 761988],
#  ['PLC_HMI', 765144],
#  ['PLC_HMI', 771167],
#  ['hidraulica_neumatica_mecanica', 761456],
#  ['hidraulica_neumatica_mecanica', 761988],
#  ['hidraulica_neumatica_mecanica', 765144],
#  ['hidraulica_neumatica_mecanica', 771167],
#  ['hidraulica_neumatica_mecanica', 761456],
#  ['hidraulica_neumatica_mecanica', 765144],
#  ['hidraulica_neumatica_mecanica', 771167],
#  ['PLC_HMI', 762040],
#  ['PLC_HMI', 762967],
#  ['PLC_HMI', 763880],
#  ['PLC_HMI', 767805],
#  ['PLC_HMI', 772381],
#  ['PLC_HMI', 773637],
#  ['hidraulica_neumatica_mecanica', 762040],
#  ['hidraulica_neumatica_mecanica', 762967],
#  ['hidraulica_neumatica_mecanica', 763880],
#  ['hidraulica_neumatica_mecanica', 767805],
#  ['hidraulica_neumatica_mecanica', 772381],
#  ['hidraulica_neumatica_mecanica', 773637],
#  ['hidraulica_neumatica_mecanica', 762040],
#  ['hidraulica_neumatica_mecanica', 762967],
#  ['hidraulica_neumatica_mecanica', 763880],
#  ['hidraulica_neumatica_mecanica', 767805],
#  ['hidraulica_neumatica_mecanica', 772381],
#  ['hidraulica_neumatica_mecanica', 773637],
#  ['montacargas', 762040],
#  ['montacargas', 762967],
#  ['montacargas', 763880],
#  ['montacargas', 767805],
#  ['montacargas', 772381],
#  ['montacargas', 773637],
#  ['Panasonic', 762040],
#  ['Panasonic', 762967],
#  ['Panasonic', 763880],
#  ['Panasonic', 767805],
#  ['Panasonic', 772381],
#  ['Panasonic', 773637],
#  ['FANUC', 762040],
#  ['FANUC', 762967],
#  ['FANUC', 763880],
#  ['FANUC', 767805],
#  ['FANUC', 772381],
#  ['FANUC', 773637],
#  ['FANUC', 762040],
#  ['FANUC', 762967],
#  ['FANUC', 763880],
#  ['FANUC', 767805],
#  ['FANUC', 772381],
#  ['FANUC', 773637],
#  ['PLC_HMI', 761736],
#  ['PLC_HMI', 764897],
#  ['PLC_HMI', 772120],
#  ['hidraulica_neumatica_mecanica', 761736],
#  ['hidraulica_neumatica_mecanica', 764897],
#  ['hidraulica_neumatica_mecanica', 772120],
#  ['hidraulica_neumatica_mecanica', 761736],
#  ['hidraulica_neumatica_mecanica', 764897],
#  ['hidraulica_neumatica_mecanica', 772120],
#  ['montacargas', 761736],
#  ['montacargas', 764897],
#  ['montacargas', 772120],
#  ['FANUC', 761736],
#  ['FANUC', 764897],
#  ['FANUC', 772120],
#  ['PLC_HMI', 761621],
#  ['PLC_HMI', 764448],
#  ['PLC_HMI', 766223],
#  ['PLC_HMI', 772849],
#  ['PLC_HMI', 773638],
#  ['PLC_HMI', 774937],
#  ['hidraulica_neumatica_mecanica', 761621],
#  ['hidraulica_neumatica_mecanica', 764448],
#  ['hidraulica_neumatica_mecanica', 766223],
#  ['hidraulica_neumatica_mecanica', 772849],
#  ['hidraulica_neumatica_mecanica', 773638],
#  ['hidraulica_neumatica_mecanica', 774937],
#  ['hidraulica_neumatica_mecanica', 761621],
#  ['hidraulica_neumatica_mecanica', 764448],
#  ['hidraulica_neumatica_mecanica', 766223],
#  ['hidraulica_neumatica_mecanica', 772849],
#  ['hidraulica_neumatica_mecanica', 773638],
#  ['hidraulica_neumatica_mecanica', 774937],
#  ['Denso', 761621],
#  ['Denso', 764448],
#  ['Denso', 766223],
#  ['Absodex', 761621],
#  ['Absodex', 764448],
#  ['Absodex', 766223],
#  ['Absodex', 772849],
#  ['Absodex', 773638],
#  ['Absodex', 774937],
#  ['IAI_Yamaha', 772849],
#  ['PLC_HMI', 761769],
#  ['PLC_HMI', 767655],
#  ['PLC_HMI', 768659],
#  ['PLC_HMI', 770895],
#  ['PLC_HMI', 775445],
#  ['hidraulica_neumatica_mecanica', 761769],
#  ['hidraulica_neumatica_mecanica', 767655],
#  ['hidraulica_neumatica_mecanica', 768659],
#  ['hidraulica_neumatica_mecanica', 770895],
#  ['hidraulica_neumatica_mecanica', 775445],
#  ['hidraulica_neumatica_mecanica', 761769],
#  ['hidraulica_neumatica_mecanica', 767655],
#  ['hidraulica_neumatica_mecanica', 768659],
#  ['hidraulica_neumatica_mecanica', 770895],
#  ['hidraulica_neumatica_mecanica', 775445],
#  ['montacargas', 761769],
#  ['montacargas', 767655],
#  ['montacargas', 768659],
#  ['montacargas', 770895],
#  ['montacargas', 775445],
#  ['alturas', 761769],
#  ['alturas', 767655],
#  ['alturas', 768659],
#  ['alturas', 770895],
#  ['alturas', 775445],
#  ['confinado', 761769],
#  ['confinado', 767655],
#  ['confinado', 768659],
#  ['confinado', 770895],
#  ['confinado', 775445],
#  ['sustancias', 761769],
#  ['sustancias', 767655],
#  ['sustancias', 768659],
#  ['sustancias', 770895],
#  ['sustancias', 775445],
#  ['KUKA', 767655],
#  ['KUKA', 770895],
#  ['KUKA', 775445],
#  ['Ingles', 769860],
#  ['Ingles', 770288],
#  ['Ingles', 773186],
#  ['Ingles', 776476],
#  ['autocad', 776546],
#  ['Uso de Portales de Clientes', 769860],
#  ['Uso de Portales de Clientes', 773186],
#  ['Uso de Portales de Clientes', 776476],
#  ['Uso de Portales de Clientes', 776546],
#  ['Sigma', 769860],
#  ['Sigma', 770288],
#  ['Sigma', 773186],
#  ['Sigma', 776476],
#  ['Core Tools', 770288],
#  ['Core Tools', 773186],
#  ['8 DS', 769860],
#  ['8 DS', 770288],
#  ['8 DS', 773186],
#  ['8 DS', 776476],
#  ['8 DS', 776546],
#  ['vsm mixel model', 769860],
#  ['vsm mixel model', 770288],
#  ['vsm mixel model', 773186],
#  ['vsm mixel model', 776476],
#  ['vsm mixel model', 776546],
#  ['IATF', 770288],
#  ['IATF', 773186],
#  ['IATF', 776476],
#  ['creating level pull', 769860],
#  ['creating level pull', 770288],
#  ['creating level pull', 773186],
#  ['creating level pull', 776476],
#  ['creating level pull', 776546],
#  ['LOTO', 761371],
#  ['LOTO', 761575],
#  ['LOTO', 769347],
#  ['LOTO', 771084],
#  ['LOTO', 772254],
#  ['LOTO', 772361],
#  ['LOTO', 776224],
#  ['termografia', 761371],
#  ['termografia', 761575],
#  ['termografia', 769347],
#  ['termografia', 771084],
#  ['termografia', 772254],
#  ['termografia', 772361],
#  ['termografia', 776224],
#  ['CQI-9', 761371],
#  ['CQI-9', 761575],
#  ['CQI-9', 769347],
#  ['CQI-9', 771084],
#  ['CQI-9', 772254],
#  ['CQI-9', 772361],
#  ['CQI-9', 776224],
#  ['CQI-11', 761371],
#  ['CQI-11', 761575],
#  ['CQI-11', 769347],
#  ['CQI-11', 771084],
#  ['CQI-11', 772254],
#  ['CQI-11', 772361],
#  ['CQI-11', 776224],
#  ['CQI-12', 761371],
#  ['CQI-12', 761575],
#  ['CQI-12', 769347],
#  ['CQI-12', 771084],
#  ['CQI-12', 772254],
#  ['CQI-12', 772361],
#  ['CQI-12', 776224],
#  ['ComercioE', 1543309],
#  ['ComercioE', 1530519],
#  ['calculo de valor de contenido regional', 1543309],
#  ['calculo de valor de contenido regional', 1530519],
#  ['auditorias electronicas y fiscalizacion', 1543309],
#  ['auditorias electronicas y fiscalizacion', 1530519],
#  ['auditorias de activo fijo: parametros para tener una correcta administracion de la maquinaria y equipo.',
#   1543309],
#  ['auditorias de activo fijo: parametros para tener una correcta administracion de la maquinaria y equipo.',
#   1530519],
#  ['Correcto_analisis', 1543309],
#  ['Correcto_analisis', 1530519],
#  ['CTPAT & OEA', 1543309],
#  ['CTPAT & OEA', 1530519],
#  ['immex', 1543309],
#  ['immex', 1530519],
#  ['CAMPA', 1543309],
#  ['CAMPA', 1530519],
#  ['anexo 24', 1543309],
#  ['anexo 24', 1530519],
#  ['aduanal', 1543309],
#  ['aduanal', 1530519],
#  ['ISO 31000', 764692],
#  ['ISO 31000', 774005],
#  ['ISO 31000', 774232],
#  ['ISO 31000', 774268],
#  ['ISO 31000', 769466],
#  ['ISO 31000', 773190],
#  ['ISO 31000', 776169],
#  ['ISO 31000', 767806],
#  ['ISO 31000', 775425],
#  ['ISO 31000', 769987],
#  ['ISO 31000', 766535],
#  ['ISO 31000', 771174],
#  ['ISO 31000', 761525],
#  ['ISO 31000', 772845],
#  ['ISO 31000', 770784],
#  ['ISO 31000', 765240],
#  ['ISO 31000', 773641],
#  ['ISO 31000', 769466],
#  ['ISO 31000', 771109],
#  ['ISO 31000', 776476],
#  ['ISO 31000', 773486],
#  ['ISO 31000', 770288],
#  ['ISO 31000', 774022],
#  ['ISO 31000', 764880],
#  ['ISO 31000', 774231],
#  ['ISO 31000', 763354],
#  ['ISO 31000', 770120],
#  ['ISO 31000', 771242],
#  ['ISO 31000', 761206],
#  ['ISO 31000', 761268],
#  ['ISO 31000', 763672],
#  ['ISO 31000', 761543],
#  ['ISO 31000', 773751],
#  ['ISO 31000', 770183],
#  ['ISO 31000', 770288],
#  ['ISO 9000', 774005],
#  ['ISO 9000', 774232],
#  ['ISO 9000', 774268],
#  ['ISO 9000', 769466],
#  ['ISO 9000', 773190],
#  ['ISO 9000', 776169],
#  ['ISO 9000', 767806],
#  ['ISO 9000', 775425],
#  ['ISO 9000', 769987],
#  ['ISO 9000', 766535],
#  ['ISO 9000', 771174],
#  ['ISO 9000', 761525],
#  ['ISO 9000', 772845],
#  ['ISO 9000', 770784],
#  ['ISO 9000', 765240],
#  ['ISO 9000', 773641],
#  ['ISO 9000', 769466],
#  ['ISO 9000', 771109],
#  ['ISO 9000', 776476],
#  ['ISO 9000', 773486],
#  ['ISO 9000', 770288],
#  ['ISO 9000', 774022],
#  ['ISO 9000', 764880],
#  ['ISO 9000', 774231],
#  ['ISO 9000', 763354],
#  ['ISO 9000', 770120],
#  ['ISO 9000', 771242],
#  ['ISO 9000', 761206],
#  ['ISO 9000', 761268],
#  ['ISO 9000', 763672],
#  ['ISO 9000', 761543],
#  ['ISO 9000', 773751],
#  ['ISO 9000', 770183],
#  ['ISO 9000', 770288],
#  ['ISO 19011', 774232],
#  ['ISO 19011', 774268],
#  ['ISO 19011', 773190],
#  ['ISO 19011', 776169],
#  ['ISO 19011', 767806],
#  ['ISO 19011', 775425],
#  ['ISO 19011', 769987],
#  ['ISO 19011', 766535],
#  ['ISO 19011', 771174],
#  ['ISO 19011', 761525],
#  ['ISO 19011', 772845],
#  ['ISO 19011', 770784],
#  ['ISO 19011', 765240],
#  ['ISO 19011', 773641],
#  ['ISO 19011', 771109],
#  ['ISO 19011', 776476],
#  ['ISO 19011', 773486],
#  ['ISO 19011', 770288],
#  ['ISO 19011', 774022],
#  ['ISO 19011', 764880],
#  ['ISO 19011', 774231],
#  ['ISO 19011', 763354],
#  ['ISO 19011', 761543],
#  ['ISO 19011', 773751],
#  ['ISO 19011', 770183],
#  ['ISO 19011', 770288],
#  ['ISO 9001', 774232],
#  ['ISO 9001', 774268],
#  ['ISO 9001', 773190],
#  ['ISO 9001', 776169],
#  ['ISO 9001', 767806],
#  ['ISO 9001', 775425],
#  ['ISO 9001', 769987],
#  ['ISO 9001', 766535],
#  ['ISO 9001', 771174],
#  ['ISO 9001', 761525],
#  ['ISO 9001', 772845],
#  ['ISO 9001', 770784],
#  ['ISO 9001', 765240],
#  ['ISO 9001', 773641],
#  ['ISO 9001', 771109],
#  ['ISO 9001', 776476],
#  ['ISO 9001', 773486],
#  ['ISO 9001', 770288],
#  ['ISO 9001', 774022],
#  ['ISO 9001', 764880],
#  ['ISO 9001', 774231],
#  ['ISO 9001', 763354],
#  ['ISO 9001', 771242],
#  ['ISO 9001', 761543],
#  ['ISO 9001', 773751],
#  ['ISO 9001', 770183],
#  ['ISO 9001', 770288],
#  ['IATF', 774232],
#  ['IATF', 774268],
#  ['IATF', 773190],
#  ['IATF', 776169],
#  ['IATF', 767806],
#  ['IATF', 775425],
#  ['IATF', 769987],
#  ['IATF', 766535],
#  ['IATF', 771174],
#  ['IATF', 761525],
#  ['IATF', 772845],
#  ['IATF', 770784],
#  ['IATF', 765240],
#  ['IATF', 773641],
#  ['IATF', 769466],
#  ['IATF', 771109],
#  ['IATF', 776476],
#  ['IATF', 773486],
#  ['IATF', 770288],
#  ['IATF', 774022],
#  ['IATF', 764880],
#  ['IATF', 774231],
#  ['IATF', 763354],
#  ['IATF', 761543],
#  ['IATF', 773751],
#  ['IATF', 770183],
#  ['IATF', 770288],
#  ['8 DS', 774232],
#  ['8 DS', 774268],
#  ['8 DS', 769466],
#  ['8 DS', 773190],
#  ['8 DS', 767806],
#  ['8 DS', 775425],
#  ['8 DS', 769987],
#  ['8 DS', 766535],
#  ['8 DS', 771174],
#  ['8 DS', 761525],
#  ['8 DS', 772845],
#  ['8 DS', 770784],
#  ['8 DS', 765240],
#  ['8 DS', 773641],
#  ['8 DS', 769466],
#  ['8 DS', 771109],
#  ['8 DS', 776476],
#  ['8 DS', 773486],
#  ['8 DS', 770288],
#  ['8 DS', 774022],
#  ['8 DS', 764880],
#  ['8 DS', 774231],
#  ['8 DS', 763354],
#  ['8 DS', 771242],
#  ['8 DS', 761206],
#  ['8 DS', 761268],
#  ['8 DS', 763672],
#  ['8 DS', 761543],
#  ['8 DS', 773751],
#  ['8 DS', 770183],
#  ['8 DS', 770288],
#  ['Core Tools', 774005],
#  ['Core Tools', 774232],
#  ['Core Tools', 774268],
#  ['Core Tools', 769466],
#  ['Core Tools', 773190],
#  ['Core Tools', 776169],
#  ['Core Tools', 767806],
#  ['Core Tools', 775425],
#  ['Core Tools', 769987],
#  ['Core Tools', 766535],
#  ['Core Tools', 771174],
#  ['Core Tools', 761525],
#  ['Core Tools', 772845],
#  ['Core Tools', 770784],
#  ['Core Tools', 765240],
#  ['Core Tools', 773641],
#  ['Core Tools', 769466],
#  ['Core Tools', 771109],
#  ['Core Tools', 776476],
#  ['Core Tools', 773486],
#  ['Core Tools', 770288],
#  ['Core Tools', 774022],
#  ['Core Tools', 764880],
#  ['Core Tools', 774231],
#  ['Core Tools', 763354],
#  ['Core Tools', 770120],
#  ['Core Tools', 761206],
#  ['Core Tools', 761268],
#  ['Core Tools', 763672],
#  ['Core Tools', 761543],
#  ['Core Tools', 773751],
#  ['Core Tools', 770183],
#  ['Core Tools', 770288],
#  ['APQP', 774268],
#  ['APQP', 769466],
#  ['APQP', 773190],
#  ['APQP', 776169],
#  ['APQP', 767806],
#  ['APQP', 775425],
#  ['APQP', 769987],
#  ['APQP', 766535],
#  ['APQP', 771174],
#  ['APQP', 761525],
#  ['APQP', 772845],
#  ['APQP', 770784],
#  ['APQP', 765240],
#  ...]

# %%
#Finalmente, se llena la Matriz de Requerimientos y Plan Anual de Capacitación (Principal), que contiene los temas (columnas) y las nóminas (índices), 
#se convierte a tipo object para permitir almacenar valores no numéricos, como la marca "x"
Principal = Principal.astype(object)
for nombre, valor in nominas:
    if valor in Principal.index and nombre in Principal.columns:
        #Para cada par [Tema, Nómina] detectado previamente, se marca con "x" la celda correspondiente en la matriz Principal para indicar que el
        #trabajador identificado por la nómina requiere capacitación en ese tema.
        Principal.loc[valor, nombre] = "x"

# %%
Principal.to_csv('DNCterminado.csv', sep=',')

# %%
Principal
# Out:
#         Core Tools Core ToolsAPQP Core ToolsPPAP PLC_HMI IATF AMEF  VDA  SPC  \
# nominas
# 776532           x            NaN            NaN     NaN    x  NaN    x  NaN
# 770479         NaN            NaN            NaN     NaN    x  NaN    x  NaN
# 763354           x            NaN            NaN     NaN    x    x    x    x
# 775239           x            NaN            NaN     NaN    x  NaN  NaN  NaN
# 861202           x            NaN            NaN     NaN    x  NaN    x  NaN
# ...            ...            ...            ...     ...  ...  ...  ...  ...
# 762375         NaN            NaN            NaN     NaN  NaN  NaN  NaN  NaN
# 761244         NaN            NaN            NaN     NaN  NaN  NaN  NaN  NaN
# 772870         NaN            NaN            NaN     NaN  NaN  NaN  NaN  NaN
# 774254         NaN            NaN            NaN     NaN  NaN  NaN  NaN  NaN
# 765420         NaN            NaN            NaN     NaN  NaN  NaN  NaN  NaN
#
#         Estadistica alturas  ... Excel Aqua pro  TPM maquina mejoras gruas  \
# nominas                      ...
# 776532          NaN     NaN  ...   NaN      NaN  NaN     NaN     NaN   NaN
# 770479          NaN     NaN  ...   NaN      NaN  NaN     NaN     NaN   NaN
# 763354          NaN     NaN  ...   NaN      NaN  NaN     NaN     NaN   NaN
# 775239          NaN     NaN  ...   NaN      NaN  NaN     NaN     NaN   NaN
# 861202          NaN     NaN  ...   NaN      NaN  NaN     NaN     NaN   NaN
# ...             ...     ...  ...   ...      ...  ...     ...     ...   ...
# 762375          NaN     NaN  ...   NaN      NaN  NaN     NaN     NaN   NaN
# 761244          NaN     NaN  ...   NaN      NaN  NaN     NaN     NaN   NaN
# 772870          NaN     NaN  ...   NaN      NaN  NaN     NaN     NaN   NaN
# 774254          NaN     NaN  ...   NaN      NaN  NaN     NaN     NaN   NaN
# 765420          NaN     NaN  ...   NaN      NaN  NaN     NaN     NaN   NaN
#
#          4ms csr's honda job observation csr's subaru
# nominas
# 776532   NaN         NaN             NaN          NaN
# 770479   NaN         NaN             NaN          NaN
# 763354   NaN         NaN             NaN          NaN
# 775239   NaN         NaN             NaN          NaN
# 861202   NaN         NaN             NaN          NaN
# ...      ...         ...             ...          ...
# 762375   NaN         NaN             NaN          NaN
# 761244   NaN         NaN             NaN          NaN
# 772870   NaN         NaN             NaN          NaN
# 774254   NaN         NaN             NaN          NaN
# 765420   NaN         NaN             NaN          NaN
#
# [343 rows x 149 columns]
